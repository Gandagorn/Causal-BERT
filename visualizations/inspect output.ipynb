# %% [markdown]
# # Imports and Installs

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install spacy==3.1.4
# !python -m spacy download de_core_news_md
# !python -m spacy download en_core_web_sm
# !pip install datasets transformers seqeval
# !pip install -q iterative-stratification
# !pip install pandas-ods-reader
# !pip install weasyprint==52.5 
# !pip install pdf2image
# !apt-get install poppler-utils
# !pip install pyyaml==5.4.1 # plotly bug
# !pip install kaleido

# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spacy==3.1.4
#   Downloading spacy-3.1.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 7.4 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (1.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (4.64.0)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (3.0.9)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 27.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (0.10.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (0.6.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (1.21.6)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 45.0 MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (0.7.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.1.4) (2.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy==3.1.4) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy==3.1.4) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy==3.1.4) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.4) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.4) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.4) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.4) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy==3.1.4) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy==3.1.4) (2.0.1)
# Installing collected packages: typing-extensions, pydantic, thinc, spacy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.9.1
#     Uninstalling pydantic-1.9.1:
#       Successfully uninstalled pydantic-1.9.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.0
#     Uninstalling thinc-8.1.0:
#       Successfully uninstalled thinc-8.1.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.1
#     Uninstalling spacy-3.4.1:
#       Successfully uninstalled spacy-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.1.4 which is incompatible.
# Successfully installed pydantic-1.8.2 spacy-3.1.4 thinc-8.0.17 typing-extensions-3.10.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting de-core-news-md==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_md-3.1.0/de_core_news_md-3.1.0-py3-none-any.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 1.3 MB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from de-core-news-md==3.1.0) (3.1.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (4.64.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.8.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.21.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.4.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (8.0.17)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.7.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.24.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.0.1)
# Installing collected packages: de-core-news-md
# Successfully installed de-core-news-md-3.1.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_md')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 6.9 MB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.1.0) (3.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.64.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.17)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.9)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.4.0
#     Uninstalling en-core-web-sm-3.4.0:
#       Successfully uninstalled en-core-web-sm-3.4.0
# Successfully installed en-core-web-sm-3.1.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 7.1 MB/s
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 44.5 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.2 MB/s
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 51.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 51.6 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 20.1 MB/s
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.4 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 43.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 51.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 40.8 MB/s
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=17509c62fc62f67569f74e0bd666d96c8db095c57c33050d1dce1ff014cf6b45
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# Installing collected packages: urllib3, pyyaml, fsspec, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, seqeval, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed datasets-2.4.0 fsspec-2022.7.1 huggingface-hub-0.8.1 multiprocess-0.70.13 pyyaml-6.0 responses-0.18.0 seqeval-1.2.2 tokenizers-0.12.1 transformers-4.21.1 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas-ods-reader
#   Downloading pandas_ods_reader-0.1.4-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pandas-ods-reader) (1.3.5)
# Collecting ezodf<0.4.0,>=0.3.2
#   Downloading ezodf-0.3.2.tar.gz (125 kB)
#      |████████████████████████████████| 125 kB 8.1 MB/s
# Requirement already satisfied: importlib_metadata<5.0.0,>=4.8.1 in /usr/local/lib/python3.7/dist-packages (from pandas-ods-reader) (4.12.0)
# Requirement already satisfied: lxml<5.0.0,>=4.6.3 in /usr/local/lib/python3.7/dist-packages (from pandas-ods-reader) (4.9.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata<5.0.0,>=4.8.1->pandas-ods-reader) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata<5.0.0,>=4.8.1->pandas-ods-reader) (3.10.0.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.0.0->pandas-ods-reader) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.0.0->pandas-ods-reader) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.0.0->pandas-ods-reader) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.0.0->pandas-ods-reader) (1.15.0)
# Building wheels for collected packages: ezodf
#   Building wheel for ezodf (setup.py) ... done
#   Created wheel for ezodf: filename=ezodf-0.3.2-py2.py3-none-any.whl size=49003 sha256=17505e54ce2d340d2ecaba4cf75579c5a84447cc5247a8c2601c155fec6e1cef
#   Stored in directory: /root/.cache/pip/wheels/8f/60/52/bffa36b97e0136aa62d54948d56e8770b96a5da7f9c65fdd85
# Successfully built ezodf
# Installing collected packages: ezodf, pandas-ods-reader
# Successfully installed ezodf-0.3.2 pandas-ods-reader-0.1.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting weasyprint==52.5
#   Downloading WeasyPrint-52.5-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 6.7 MB/s
# Collecting cairocffi>=0.9.0
#   Downloading cairocffi-1.3.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 9.6 MB/s
# Collecting tinycss2>=1.0.0
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Collecting Pyphen>=0.9.1
#   Downloading pyphen-0.12.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 52.0 MB/s
# Requirement already satisfied: setuptools>=39.2.0 in /usr/local/lib/python3.7/dist-packages (from weasyprint==52.5) (57.4.0)
# Collecting cssselect2>=0.1
#   Downloading cssselect2-0.6.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: Pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from weasyprint==52.5) (7.1.2)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/dist-packages (from weasyprint==52.5) (1.15.1)
# Requirement already satisfied: html5lib>=0.999999999 in /usr/local/lib/python3.7/dist-packages (from weasyprint==52.5) (1.0.1)
# Collecting CairoSVG>=2.4.0
#   Downloading CairoSVG-2.5.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.3 MB/s
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from CairoSVG>=2.4.0->weasyprint==52.5) (0.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=0.6->weasyprint==52.5) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from cssselect2>=0.1->weasyprint==52.5) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib>=0.999999999->weasyprint==52.5) (1.15.0)
# Building wheels for collected packages: cairocffi
#   Building wheel for cairocffi (setup.py) ... done
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89668 sha256=1851a5b04cae8fd5a634b3e4654c27377eb8dc08e24beb10671fb25553cd9859
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# Installing collected packages: tinycss2, cssselect2, cairocffi, Pyphen, CairoSVG, weasyprint
# Successfully installed CairoSVG-2.5.2 Pyphen-0.12.0 cairocffi-1.3.0 cssselect2-0.6.0 tinycss2-1.1.1 weasyprint-52.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pdf2image
#   Downloading pdf2image-1.16.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pdf2image) (7.1.2)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (169 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155680 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyyaml==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 8.1 MB/s
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed pyyaml-5.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 128 kB/s
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
import spacy
import pandas as pd
import numpy as np
from tqdm import tqdm
from collections import defaultdict
from spacy import displacy
import re
import pickle
import torch
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification, AutoTokenizer, AutoModel, get_scheduler, BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from datasets import load_dataset, load_metric, Dataset, DatasetDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
from torch.utils.data import Dataset as TDataset
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import networkx as nx
import seaborn as sns                      
import matplotlib.pyplot as plt
from seqeval.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report as classification_report_sk
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from pandas_ods_reader import read_ods
from IPython.core.display import display as display_html, HTML as jupyter_HTML
from weasyprint import HTML, CSS
from pdf2image import convert_from_path
import datetime
import functools
import os
import json
import itertools
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import plotly.express as px
pd.plotting.backend = "plotly"

pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
PROJECT_PATH = "/content/drive/My Drive/master thesis/"
FONDSFORSTE_DATSET_PATH = "/content/drive/My Drive/master thesis/data/fondsforste/"
FORSTVERMESSUNG_DATSET_PATH = "/content/drive/My Drive/master thesis/data/forstvermessung/"
REHBEIN_DATA_PATH = "/content/drive/My Drive/master thesis/data/causal_language_DE_release1.0/"
DUNIETZ_DATA_PATH = "/content/drive/My Drive/master thesis/data/BECAUSE/"
CURRENT_TIME = datetime.datetime.now().strftime('%Y_%m_%d_%H%M')

import sys
sys.path.append(PROJECT_PATH + "code/historic/")

from helper_functions import *
from model import *
from metrics import *
from visualization import *
from training_utils import *

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
num_relations = pd.DataFrame({
    "German (SF & FV)": {
        "Cause": 488,
        "Effect": 498,
        "Actor": 52,
        "Aff.": 80,
        "Sup.": 12,
        "Contr.": 53,
    },
    "English (BECAUSE)": {
        "Cause": 10,
        "Effect": 10,
        "Actor": "-",
        "Aff.": "-",
        "Sup.": "-",
        "Contr.": "-",
    }
})

print(num_relations.to_latex())
# Out:
# \begin{tabular}{lrl}
# \toprule
# {} &  German (SF \& FV) & English (BECAUSE) \\
# \midrule
# Cause  &               488 &                10 \\
# Effect &               498 &                10 \\
# Actor  &                52 &                 - \\
# Aff.   &                80 &                 - \\
# Sup.   &                12 &                 - \\
# Contr. &                53 &                 - \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Params and Config

# %%
tqdm.pandas()

causal_arguments = ["Cause", "Effect", "Affected", "Actor", "Controlling", "Support", "Trigger"]

entity_options = {
    'colors': {
        'Cause': '#99FCE0',
        'Effect': '#6779CB',
        'Affected': '#84F72D',
        'Actor': '#108482',
        'Controlling': '#E3AF32',
        'Support': '#C44C6D',
        'Trigger': '#C5E95E',
    },
    'ents': causal_arguments
}

config = {
    "seed": 42,
    "test_size": 0.2,
    "val_size": 0.1,
    "models_directory": PROJECT_PATH + f"models/{CURRENT_TIME}/",
    "rehbein_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_rehbein",
    "dunietz_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_dunietz",
    "rehbein_dunietz_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_rehbein_dunietz",
    "fondsforste_rehbein_dunietz_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_fondsforste_rehbein_dunietz",
    "forstvermessung_rehbein_dunietz_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_forstvermessung_rehbein_dunietz",
    "fondsforste_forstvermessung_rehbein_dunietz_model_file_path": PROJECT_PATH + "models/pretrained/CBERT_fondsforste_forstvermessung_rehbein_dunietz",
    "retrain_pretrained": False,
    "model_checkpoints": [
                        #   "dbmdz/bert-base-german-uncased", 
                          "dbmdz/bert-base-german-cased",
                          "dbmdz/bert-base-german-europeana-cased",
                          "bert-base-multilingual-cased",
    ],
    "batch_size": 2,
    "max_length": 500,
    "num_epochs": 75,
    "learning_rate": 2.5e-5,
    "bert_embedding_size": 768,
    "bert_dropout": 0.1,
    "early_stop_patience": 5,
    "causal_arguments": causal_arguments,
    "nlp_ger": spacy.load('de_core_news_md'),
    "nlp_eng": spacy.load("en_core_web_sm"),
    "entity_options": entity_options,
    "val_epochs": 5,
    "add_coreference": False,
    "debug": False,
    "time": CURRENT_TIME,
    "use_normalized": False,
}
    
if config["debug"]:
    config["num_epochs"] = 1
    config["model_checkpoints"] = config["model_checkpoints"][:1]
    config["models_directory"] = config["models_directory"][:-1] + "_debug/"
    config["rehbein_model_file_path"] = config["rehbein_model_file_path"] + "_debug"
    config["dunietz_model_file_path"] = config["dunietz_model_file_path"] + "_debug"
    config["rehbein_dunietz_model_file_path"] = config["rehbein_dunietz_model_file_path"] + "_debug"
    config["fondsforste_rehbein_dunietz_model_file_path"] = config["fondsforste_rehbein_dunietz_model_file_path"] + "_debug"
    config["forstvermessung_rehbein_dunietz_model_file_path"] = config["forstvermessung_rehbein_dunietz_model_file_path"] + "_debug"
    config["fondsforste_forstvermessung_rehbein_dunietz_model_file_path"] = config["fondsforste_forstvermessung_rehbein_dunietz_model_file_path"] + "_debug"

try:
    os.mkdir(config["models_directory"])
except:
    print(f"Model directory {config['models_directory']} already created")

config["label_dict"] = {
    'B-Trigger': 0,
    'O': 1, # "Trigger" and "O" 012 so that Trigger-Detection task is automatically aligned
    'B-Actor': 2,
    'I-Actor': 3,
    'B-Affected': 4,
    'I-Affected': 5,
    'B-Cause': 6,
    'I-Cause': 7,
    'B-Controlling': 8,
    'I-Controlling': 9,
    'B-Effect': 10,
    'I-Effect': 11,
    'B-Support': 12,
    'I-Support': 13,
}

config["type_dict"] = {
    "Purpose": 0,
    "Motivation": 1,
    "Consequence": 2,
    "None": 3,
}

config["degree_dict"] = {
    "Facilitate": 0,
    "Inhibit": 1,
    "None": 2,
}

config["label_list"] = list(config["label_dict"].keys())
config["type_list"] = list(config["type_dict"].keys())
config["degree_list"] = list(config["degree_dict"].keys())

metric = load_metric("seqeval")
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# https://stackoverflow.com/questions/26646362/numpy-array-is-not-json-serializable
class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

print(config)
# Out:
# Downloading builder script:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# {'seed': 42, 'test_size': 0.2, 'val_size': 0.1, 'models_directory': '/content/drive/My Drive/master thesis/models/2022_08_15_1902/', 'rehbein_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_rehbein', 'dunietz_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_dunietz', 'rehbein_dunietz_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_rehbein_dunietz', 'fondsforste_rehbein_dunietz_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_fondsforste_rehbein_dunietz', 'forstvermessung_rehbein_dunietz_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_forstvermessung_rehbein_dunietz', 'fondsforste_forstvermessung_rehbein_dunietz_model_file_path': '/content/drive/My Drive/master thesis/models/pretrained/CBERT_fondsforste_forstvermessung_rehbein_dunietz', 'retrain_pretrained': False, 'model_checkpoints': ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased'], 'batch_size': 2, 'max_length': 500, 'num_epochs': 75, 'learning_rate': 2.5e-05, 'bert_embedding_size': 768, 'bert_dropout': 0.1, 'early_stop_patience': 5, 'causal_arguments': ['Cause', 'Effect', 'Affected', 'Actor', 'Controlling', 'Support', 'Trigger'], 'nlp_ger': <spacy.lang.de.German object at 0x7f8064b4ec10>, 'nlp_eng': <spacy.lang.en.English object at 0x7f806492c450>, 'entity_options': {'colors': {'Cause': '#99FCE0', 'Effect': '#6779CB', 'Affected': '#84F72D', 'Actor': '#108482', 'Controlling': '#E3AF32', 'Support': '#C44C6D', 'Trigger': '#C5E95E'}, 'ents': ['Cause', 'Effect', 'Affected', 'Actor', 'Controlling', 'Support', 'Trigger']}, 'val_epochs': 5, 'add_coreference': False, 'debug': False, 'time': '2022_08_15_1902', 'use_normalized': False, 'label_dict': {'B-Trigger': 0, 'O': 1, 'B-Actor': 2, 'I-Actor': 3, 'B-Affected': 4, 'I-Affected': 5, 'B-Cause': 6, 'I-Cause': 7, 'B-Controlling': 8, 'I-Controlling': 9, 'B-Effect': 10, 'I-Effect': 11, 'B-Support': 12, 'I-Support': 13}, 'type_dict': {'Purpose': 0, 'Motivation': 1, 'Consequence': 2, 'None': 3}, 'degree_dict': {'Facilitate': 0, 'Inhibit': 1, 'None': 2}, 'label_list': ['B-Trigger', 'O', 'B-Actor', 'I-Actor', 'B-Affected', 'I-Affected', 'B-Cause', 'I-Cause', 'B-Controlling', 'I-Controlling', 'B-Effect', 'I-Effect', 'B-Support', 'I-Support'], 'type_list': ['Purpose', 'Motivation', 'Consequence', 'None'], 'degree_list': ['Facilitate', 'Inhibit', 'None']}

# %% [markdown]
# # Visualize Results

# %%
baseline_corpus_name = "evaluation_data"
baseline_model_name = "baseline"
baseline_time = "2022_07_22_1950"

baseline_results_path = PROJECT_PATH + f"output/{baseline_time}_baseline/"  + f"{baseline_corpus_name}_predictions_{baseline_time}_{baseline_model_name}.json"

with open(baseline_results_path, "r") as f:
    baseline_results = json.load(f)

baseline_results.keys()
# Out:
# dict_keys(['dbmdz/bert-base-german-cased'])

# %%
transfer_learning_names_dict = {
    "no_transfer": "\multirow{3}{*}{\makecell{---}}",
    "rehbein": "RULE" "\multirow{3}{*}{\makecell{\textbf{R&R}}}",
    "dunietz": "RULE" "\multirow{3}{*}{\makecell{\textbf{BEC}}}",
    "rehbein_dunietz": "RULE" "\multirow{3}{*}{\textbf{\makecell{R&R, \\\\ BEC}}}",
}

transfer_learning_names_dict_base = {
    "no_transfer": "\u2014",
    "rehbein": "R&R",
    "dunietz": "BEC",
    "rehbein_dunietz": "R&R, BEC",
}


model_names_dict = {
    "dbmdz/bert-base-german-cased": "\textbf{Ger.}",
    "dbmdz/bert-base-german-europeana-cased": "\textbf{Europ.}",
    "bert-base-multilingual-cased": "\textbf{Multi.}",
}


metrics_dict = {
    "MCC": "MCC",
    "accuracy": "Accuracy",
    "consequence_f1": "\makecell{Consequence\\\\ F1}",
    "motivation_f1": "\makecell{Motivation\\\\ F1}",
    "purpose_f1": "\makecell{Purpose\\\\ F1}",
    "facilitate_f1": "Facilitate F1",
    "inhibit_f1": "Inhibit F1",
    "precision": "Precision",
    "recall": "Recall",
    "f1": "F1",
    "strict": "Strict",
    "relaxed": "Relaxed",
}

# %%
# proposed: [no finetuning, rehbein, dunietz, rehbein_dunietz]
corpus_name = "evaluation_data"

# normal
time = "2022_07_19_2043" 
name = "normal_valid"

# normalized
norm_time = "2022_07_23_2143"
norm_name = "normalization"

# coref
coref_time = "2022_07_23_2143"
coref_name = "coref"

# %%
def bold_largest(s):
    mean_part = s.str.split().str[0].astype(float)
    std_part = s.str.split().str[1:].str.join(" ")

    bolded_res = ["\textbf{" + str(mean) + " " + stddev + "}" if mean == mean_part.max() and mean > 0 else str(mean) + " " + stddev for mean, stddev in zip(mean_part, std_part)]
    return pd.Series(bolded_res, name=s.name, index=s.index)

# %% [markdown]
# ## Trigger Results

# %%
combined_results = []

# baseline
baseline_metric_results = {}
metric_results_model = {}
for match_metric in ["precision", "recall", "f1"]:
    match_metric_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_trigger_results"][f"overall_{match_metric}_strict"] for fold in range(5)]) * 100
    match_metric_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_trigger_results"][f"overall_{match_metric}_strict"] for fold in range(5)]) * 100
    metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

baseline_metric_results["Baseline"] = metric_results_model

# experiment
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for match_metric in ["precision", "recall", "f1"]:
            match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_trigger_results"][f"overall_{match_metric}_strict"] for fold in range(5)]) * 100
            match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_trigger_results"][f"overall_{match_metric}_strict"] for fold in range(5)]) * 100
            metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results.append(pd.DataFrame(baseline_metric_results).T)
combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"],
    "  ": combined_results.index,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)
# sort in order
combined_results = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Precision", "Recall", "F1"]]]

combined_results

metric_kind_results = combined_results
metric_kind_results = metric_kind_results.T

index_df = pd.DataFrame({
    "  ": ["\textbf{Trigger}"] * 3,
    " ": metric_kind_results.index,
})

metric_kind_results.index = pd.MultiIndex.from_frame(index_df)
metric_kind_results = metric_kind_results.T

# make largest result bold
metric_kind_results = metric_kind_results.apply(bold_largest, axis=0)
display(metric_kind_results)

# convert to latex and change some things
latex_df = metric_kind_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllllll", "clcccccc")
latex_df = latex_df.replace(".0", "")
latex_df = latex_df.replace("\multicolumn{3}{l}", "\multicolumn{3}{c}")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Precision\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Precision}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                                      \textbf{Trigger}  \
#                                                                    \textbf{Precision}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}    \textbf{50.1 (3)}
#                                                    \textbf{Europ.}           49.3 (2)
#                                                    \textbf{Multi.}           45.1 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             48.5 (4)
#                                                    \textbf{Europ.}           49.0 (3)
#                                                    \textbf{Multi.}           45.5 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             42.6 (2)
#                                                    \textbf{Europ.}           44.5 (1)
#                                                    \textbf{Multi.}           41.7 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             45.1 (3)
#                                                    \textbf{Europ.}           47.1 (3)
#                                                    \textbf{Multi.}           43.2 (3)
# Baseline                                           Baseline                  26.9 (3)
#
#                                                                                        \
#                                                                       \textbf{Recall}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             56.7 (2)
#                                                    \textbf{Europ.}           53.2 (2)
#                                                    \textbf{Multi.}           51.9 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             54.7 (1)
#                                                    \textbf{Europ.}           53.1 (4)
#                                                    \textbf{Multi.}           50.9 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             56.9 (2)
#                                                    \textbf{Europ.}  \textbf{57.3 (2)}
#                                                    \textbf{Multi.}           52.2 (4)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             54.3 (2)
#                                                    \textbf{Europ.}           54.3 (3)
#                                                    \textbf{Multi.}           52.0 (3)
# Baseline                                           Baseline                  45.7 (4)
#
#
#                                                                           \textbf{F1}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}    \textbf{53.1 (2)}
#                                                    \textbf{Europ.}           51.1 (2)
#                                                    \textbf{Multi.}           48.2 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             51.4 (3)
#                                                    \textbf{Europ.}           50.8 (2)
#                                                    \textbf{Multi.}           48.0 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             48.6 (1)
#                                                    \textbf{Europ.}           50.0 (1)
#                                                    \textbf{Multi.}           46.3 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             49.2 (2)
#                                                    \textbf{Europ.}           50.4 (3)
#                                                    \textbf{Multi.}           47.1 (3)
# Baseline                                           Baseline                  33.8 (3)
# \begin{tabular}{lllll}
# \toprule
#          &    & \multicolumn{3}{c}{\textbf{Trigger}} \\
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &  \textbf{50.1 (3)} &           56.7 (2) &  \textbf{53.1 (2)} \\
#          & \textbf{Europ.} &           49.3 (2) &           53.2 (2) &           51.1 (2) \\
#          & \textbf{Multi.} &           45.1 (4) &           51.9 (2) &           48.2 (2) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           48.5 (4) &           54.7 (1) &           51.4 (3) \\
#          & \textbf{Europ.} &           49 (3) &           53.1 (4) &           50.8 (2) \\
#          & \textbf{Multi.} &           45.5 (4) &           50.9 (2) &           48 (3) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           42.6 (2) &           56.9 (2) &           48.6 (1) \\
#          & \textbf{Europ.} &           44.5 (1) &  \textbf{57.3 (2)} &           50 (1) \\
#          & \textbf{Multi.} &           41.7 (3) &           52.2 (4) &           46.3 (3) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &           45.1 (3) &           54.3 (2) &           49.2 (2) \\
#          & \textbf{Europ.} &           47.1 (3) &           54.3 (3) &           50.4 (3) \\
#          & \textbf{Multi.} &           43.2 (3) &           52 (3) &           47.1 (3) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &           26.9 (3) &           45.7 (4) &           33.8 (3) \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Argument Results

# %%
trigger_res = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # baseline
    baseline_metric_results = {}
    metric_results_model = {}
    trigger_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
    trigger_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
    metric_results_model["\textbf{" + "Trigger" + "}"] = f"{trigger_mean:.1f} ({trigger_std:.0f})"

    for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
        c_arg_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
        c_arg_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
        
        if c_arg == "Controlling": c_arg = "Contr."
        if c_arg == "Affected": c_arg = "Aff."
        if c_arg == "Support": c_arg = "Sup."
        metric_results_model["\textbf{" + c_arg + "}"] = f"{c_arg_mean:.1f} ({c_arg_std:.0f})"

    baseline_metric_results["Baseline"] = metric_results_model


    # experiment
    transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
    for tl_name in transfer_learning_names:

        results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

            metric_results_model = {}
            trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            metric_results_model["\textbf{" + "Trigger" + "}"] = f"{trigger_mean:.1f} ({trigger_std:.0f})"

            for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                
                if c_arg == "Controlling": c_arg = "Contr."
                if c_arg == "Affected": c_arg = "Aff."
                if c_arg == "Support": c_arg = "Sup."
                metric_results_model["\textbf{" + c_arg + "}"] = f"{c_arg_mean:.1f} ({c_arg_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results.append(pd.DataFrame(baseline_metric_results).T)
    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"],
        "  ": combined_results.index,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    # make largest result bold
    combined_results = combined_results.apply(bold_largest, axis=0)

    combined_results_sub = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Cause", "Effect", "Actor", "Aff.", "Sup.", "Contr."]]]
    display(combined_results_sub)

    # convert to latex and change some things
    latex_df = combined_results_sub.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
    latex_df = latex_df.replace("RULE", "\hline\n")
    latex_df = latex_df.replace("llllllll", "clcccccc")
    latex_df = latex_df.replace(".0", "")
    latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Cause\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Cause}", latex_df, flags=re.MULTILINE)
    print(metric_kind)
    print(latex_df)

detect_trigger_res = combined_results["\textbf{Trigger}"]
display(pd.DataFrame(detect_trigger_res))
latex_df = detect_trigger_res.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("lll", "clc")
latex_df = latex_df.replace(".0", "")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Trigger\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Trigger}", latex_df, flags=re.MULTILINE)
print("Trigger")
print(latex_df)
# Out:
#                                                                        \textbf{Cause}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             25.6 (3)
#                                                    \textbf{Europ.}           23.5 (5)
#                                                    \textbf{Multi.}           23.9 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             27.3 (4)
#                                                    \textbf{Europ.}           22.0 (4)
#                                                    \textbf{Multi.}           26.8 (5)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             26.4 (3)
#                                                    \textbf{Europ.}           27.9 (4)
#                                                    \textbf{Multi.}           26.4 (4)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             28.7 (2)
#                                                    \textbf{Europ.}  \textbf{30.3 (5)}
#                                                    \textbf{Multi.}           27.4 (4)
# Baseline                                           Baseline                   0.7 (0)
#
#                                                                       \textbf{Effect}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             24.7 (3)
#                                                    \textbf{Europ.}           23.5 (5)
#                                                    \textbf{Multi.}           22.5 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             25.8 (5)
#                                                    \textbf{Europ.}           22.9 (2)
#                                                    \textbf{Multi.}           25.2 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             29.8 (3)
#                                                    \textbf{Europ.}           29.4 (3)
#                                                    \textbf{Multi.}           26.8 (4)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{31.0 (5)}
#                                                    \textbf{Europ.}           27.2 (4)
#                                                    \textbf{Multi.}           27.7 (4)
# Baseline                                           Baseline                   0.7 (0)
#
#                                                                         \textbf{Actor}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             32.7 (12)
#                                                    \textbf{Europ.}  \textbf{34.3 (16)}
#                                                    \textbf{Multi.}           27.8 (14)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             29.6 (10)
#                                                    \textbf{Europ.}            29.5 (9)
#                                                    \textbf{Multi.}           31.4 (16)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}              31.3 (8)
#                                                    \textbf{Europ.}           30.6 (12)
#                                                    \textbf{Multi.}            27.5 (8)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             33.0 (13)
#                                                    \textbf{Europ.}           33.4 (11)
#                                                    \textbf{Multi.}            34.0 (9)
# Baseline                                           Baseline                   5.0 (10)
#
#                                                                         \textbf{Aff.}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             20.0 (8)
#                                                    \textbf{Europ.}           16.1 (7)
#                                                    \textbf{Multi.}            9.9 (6)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             20.2 (8)
#                                                    \textbf{Europ.}           17.8 (5)
#                                                    \textbf{Multi.}           13.9 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             20.6 (3)
#                                                    \textbf{Europ.}  \textbf{25.2 (6)}
#                                                    \textbf{Multi.}           19.4 (8)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             20.5 (6)
#                                                    \textbf{Europ.}           18.7 (5)
#                                                    \textbf{Multi.}          21.3 (10)
# Baseline                                           Baseline                   0.0 (0)
#
#                                                                    \textbf{Sup.}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# Baseline                                           Baseline              0.0 (0)
#
#                                                                      \textbf{Contr.}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             8.0 (5)
#                                                    \textbf{Europ.}           3.5 (5)
#                                                    \textbf{Multi.}           5.6 (8)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}    \textbf{9.0 (3)}
#                                                    \textbf{Europ.}           5.4 (5)
#                                                    \textbf{Multi.}           8.3 (5)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             8.7 (4)
#                                                    \textbf{Europ.}           8.8 (6)
#                                                    \textbf{Multi.}           7.9 (5)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             5.8 (5)
#                                                    \textbf{Europ.}           8.8 (9)
#                                                    \textbf{Multi.}           6.5 (7)
# Baseline                                           Baseline                  0.0 (0)
# strict
# \begin{tabular}{clcccccc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Cause} &    \textbf{Effect} &      \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &   \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &           25.6 (3) &           24.7 (3) &           32.7 (12) &           20 (8) &       0 (0) &           8 (5) \\
#          & \textbf{Europ.} &           23.5 (5) &           23.5 (5) &  \textbf{34.3 (16)} &           16.1 (7) &       0 (0) &           3.5 (5) \\
#          & \textbf{Multi.} &           23.9 (3) &           22.5 (4) &           27.8 (14) &            9.9 (6) &       0 (0) &           5.6 (8) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           27.3 (4) &           25.8 (5) &           29.6 (10) &           20.2 (8) &       0 (0) &  \textbf{9 (3)} \\
#          & \textbf{Europ.} &           22 (4) &           22.9 (2) &            29.5 (9) &           17.8 (5) &       0 (0) &           5.4 (5) \\
#          & \textbf{Multi.} &           26.8 (5) &           25.2 (4) &           31.4 (16) &           13.9 (4) &       0 (0) &           8.3 (5) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           26.4 (3) &           29.8 (3) &            31.3 (8) &           20.6 (3) &       0 (0) &           8.7 (4) \\
#          & \textbf{Europ.} &           27.9 (4) &           29.4 (3) &           30.6 (12) &  \textbf{25.2 (6)} &       0 (0) &           8.8 (6) \\
#          & \textbf{Multi.} &           26.4 (4) &           26.8 (4) &            27.5 (8) &           19.4 (8) &       0 (0) &           7.9 (5) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &           28.7 (2) &  \textbf{31 (5)} &           33 (13) &           20.5 (6) &       0 (0) &           5.8 (5) \\
#          & \textbf{Europ.} &  \textbf{30.3 (5)} &           27.2 (4) &           33.4 (11) &           18.7 (5) &       0 (0) &           8.8 (9) \\
#          & \textbf{Multi.} &           27.4 (4) &           27.7 (4) &            34 (9) &          21.3 (10) &       0 (0) &           6.5 (7) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &            0.7 (0) &            0.7 (0) &            5 (10) &            0 (0) &       0 (0) &           0 (0) \\
# \bottomrule
# \end{tabular}
#                                                                        \textbf{Cause}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             49.6 (2)
#                                                    \textbf{Europ.}           47.6 (3)
#                                                    \textbf{Multi.}           46.3 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             51.5 (4)
#                                                    \textbf{Europ.}           47.1 (2)
#                                                    \textbf{Multi.}           50.4 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             51.5 (4)
#                                                    \textbf{Europ.}  \textbf{53.2 (2)}
#                                                    \textbf{Multi.}           52.0 (4)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             52.7 (2)
#                                                    \textbf{Europ.}  \textbf{53.2 (2)}
#                                                    \textbf{Multi.}           52.3 (4)
# Baseline                                           Baseline                  19.3 (3)
#
#                                                                       \textbf{Effect}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             52.7 (3)
#                                                    \textbf{Europ.}           51.8 (4)
#                                                    \textbf{Multi.}           52.5 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             54.8 (2)
#                                                    \textbf{Europ.}           50.9 (5)
#                                                    \textbf{Multi.}           54.5 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             58.2 (4)
#                                                    \textbf{Europ.}           56.9 (3)
#                                                    \textbf{Multi.}           55.0 (5)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{59.4 (3)}
#                                                    \textbf{Europ.}           56.1 (3)
#                                                    \textbf{Multi.}           56.5 (7)
# Baseline                                           Baseline                  24.1 (2)
#
#                                                                         \textbf{Actor}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             44.5 (17)
#                                                    \textbf{Europ.}  \textbf{47.7 (15)}
#                                                    \textbf{Multi.}           29.7 (16)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             42.6 (13)
#                                                    \textbf{Europ.}           39.3 (13)
#                                                    \textbf{Multi.}           38.0 (15)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             36.7 (13)
#                                                    \textbf{Europ.}           39.1 (15)
#                                                    \textbf{Multi.}            34.7 (9)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             36.0 (13)
#                                                    \textbf{Europ.}           44.2 (17)
#                                                    \textbf{Multi.}           42.1 (16)
# Baseline                                           Baseline                   19.8 (9)
#
#                                                                         \textbf{Aff.}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             23.5 (8)
#                                                    \textbf{Europ.}           22.4 (8)
#                                                    \textbf{Multi.}           16.6 (9)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}            27.2 (13)
#                                                    \textbf{Europ.}           23.3 (8)
#                                                    \textbf{Multi.}           18.1 (7)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             27.0 (7)
#                                                    \textbf{Europ.}  \textbf{28.8 (7)}
#                                                    \textbf{Multi.}           26.2 (8)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             28.7 (8)
#                                                    \textbf{Europ.}           26.5 (8)
#                                                    \textbf{Multi.}           25.1 (8)
# Baseline                                           Baseline                   1.9 (4)
#
#                                                                    \textbf{Sup.}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}         0.0 (0)
#                                                    \textbf{Europ.}       0.0 (0)
#                                                    \textbf{Multi.}       0.0 (0)
# Baseline                                           Baseline              0.0 (0)
#
#                                                                       \textbf{Contr.}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}            24.8 (10)
#                                                    \textbf{Europ.}           15.9 (6)
#                                                    \textbf{Multi.}            8.7 (6)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}    \textbf{29.5 (6)}
#                                                    \textbf{Europ.}           18.7 (7)
#                                                    \textbf{Multi.}           13.0 (7)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             19.9 (2)
#                                                    \textbf{Europ.}          25.2 (10)
#                                                    \textbf{Multi.}           22.4 (6)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             18.7 (3)
#                                                    \textbf{Europ.}           18.7 (7)
#                                                    \textbf{Multi.}           15.1 (9)
# Baseline                                           Baseline                  10.3 (8)
# relaxed
# \begin{tabular}{clcccccc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Cause} &    \textbf{Effect} &      \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &    \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &           49.6 (2) &           52.7 (3) &           44.5 (17) &           23.5 (8) &       0 (0) &          24.8 (10) \\
#          & \textbf{Europ.} &           47.6 (3) &           51.8 (4) &  \textbf{47.7 (15)} &           22.4 (8) &       0 (0) &           15.9 (6) \\
#          & \textbf{Multi.} &           46.3 (2) &           52.5 (3) &           29.7 (16) &           16.6 (9) &       0 (0) &            8.7 (6) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           51.5 (4) &           54.8 (2) &           42.6 (13) &          27.2 (13) &       0 (0) &  \textbf{29.5 (6)} \\
#          & \textbf{Europ.} &           47.1 (2) &           50.9 (5) &           39.3 (13) &           23.3 (8) &       0 (0) &           18.7 (7) \\
#          & \textbf{Multi.} &           50.4 (3) &           54.5 (2) &           38 (15) &           18.1 (7) &       0 (0) &           13 (7) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           51.5 (4) &           58.2 (4) &           36.7 (13) &           27 (7) &       0 (0) &           19.9 (2) \\
#          & \textbf{Europ.} &  \textbf{53.2 (2)} &           56.9 (3) &           39.1 (15) &  \textbf{28.8 (7)} &       0 (0) &          25.2 (10) \\
#          & \textbf{Multi.} &           52 (4) &           55 (5) &            34.7 (9) &           26.2 (8) &       0 (0) &           22.4 (6) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &           52.7 (2) &  \textbf{59.4 (3)} &           36 (13) &           28.7 (8) &       0 (0) &           18.7 (3) \\
#          & \textbf{Europ.} &  \textbf{53.2 (2)} &           56.1 (3) &           44.2 (17) &           26.5 (8) &       0 (0) &           18.7 (7) \\
#          & \textbf{Multi.} &           52.3 (4) &           56.5 (7) &           42.1 (16) &           25.1 (8) &       0 (0) &           15.1 (9) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &           19.3 (3) &           24.1 (2) &            19.8 (9) &            1.9 (4) &       0 (0) &           10.3 (8) \\
# \bottomrule
# \end{tabular}
#                                                                      \textbf{Trigger}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}    \textbf{53.1 (2)}
#                                                    \textbf{Europ.}           51.1 (2)
#                                                    \textbf{Multi.}           48.2 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             51.4 (3)
#                                                    \textbf{Europ.}           50.8 (2)
#                                                    \textbf{Multi.}           48.0 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             48.6 (1)
#                                                    \textbf{Europ.}           50.0 (1)
#                                                    \textbf{Multi.}           46.3 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             49.2 (2)
#                                                    \textbf{Europ.}           50.4 (3)
#                                                    \textbf{Multi.}           47.1 (3)
# Baseline                                           Baseline                  33.8 (3)
# Trigger
# \begin{tabular}{clc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Trigger} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &  \textbf{53.1 (2)} \\
#          & \textbf{Europ.} &           51.1 (2) \\
#          & \textbf{Multi.} &           48.2 (2) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           51.4 (3) \\
#          & \textbf{Europ.} &           50.8 (2) \\
#          & \textbf{Multi.} &           48 (3) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           48.6 (1) \\
#          & \textbf{Europ.} &           50 (1) \\
#          & \textbf{Multi.} &           46.3 (3) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &           49.2 (2) \\
#          & \textbf{Europ.} &           50.4 (3) \\
#          & \textbf{Multi.} &           47.1 (3) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &           33.8 (3) \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results_all = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # baseline
    metric_results = {}
    metric_results_model = {}
    trigger_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
    trigger_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
    metric_results_model["Trigger"] = trigger_mean

    for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
        c_arg_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
        c_arg_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
        metric_results_model[c_arg] = c_arg_mean

    metric_results["Baseline"] = metric_results_model
    combined_results.append(pd.DataFrame(metric_results).T)


    # experiment
    transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
    for tl_name in transfer_learning_names:

        results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

            metric_results_model = {}
            trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            metric_results_model["Trigger"] = trigger_mean

            for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                metric_results_model[c_arg] = c_arg_mean

            metric_results[model_kind] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        "Transfer": ["Baseline"] + flatten([[tl_name] * 3 for tl_name in ["\u2014", "BEC", "R&R", "R&R, BEC"]]),
        "BERT": ["Baseline"] + ["German", "Europeana", "Multilingual"]*4,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    combined_results_sub = combined_results[[c_arg for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]]]
    combined_results_sub["kind"] = metric_kind.title()

    combined_results_all.append(combined_results_sub)

combined_results_all = pd.concat(combined_results_all, axis=0).reset_index()
combined_results_all = combined_results_all[combined_results_all["Transfer"] != "Baseline"].copy()
combined_results_all["Macro F1"] = combined_results_all[["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]].mean(axis=1)

combined_results_all
# Out:
#     Transfer          BERT      Cause     Effect      Actor   Affected  \
# 1          —        German  25.555826  24.743564  32.740436  19.964839
# 2          —     Europeana  23.470145  23.488848  34.250275  16.098103
# 3          —  Multilingual  23.924953  22.480360  27.841897   9.900142
# 4        BEC        German  27.306735  25.814670  29.592922  20.220313
# 5        BEC     Europeana  22.047002  22.851320  29.471264  17.759290
# 6        BEC  Multilingual  26.752080  25.235085  31.383459  13.918475
# 7        R&R        German  26.389672  29.764783  31.306295  20.575285
# 8        R&R     Europeana  27.877048  29.360050  30.555556  25.199219
# 9        R&R  Multilingual  26.440911  26.785411  27.547410  19.356811
# 10  R&R, BEC        German  28.687005  31.025641  33.039614  20.469040
# 11  R&R, BEC     Europeana  30.261288  27.179646  33.440293  18.679902
# 12  R&R, BEC  Multilingual  27.387547  27.717029  33.973064  21.334925
# 14         —        German  49.550221  52.690052  44.521596  23.482625
# 15         —     Europeana  47.555585  51.826479  47.662369  22.449322
# 16         —  Multilingual  46.329733  52.548325  29.660079  16.604818
# 17       BEC        German  51.525570  54.763312  42.583226  27.203276
# 18       BEC     Europeana  47.143170  50.902015  39.267241  23.335960
# 19       BEC  Multilingual  50.350512  54.481459  37.954887  18.057364
# 20       R&R        German  51.505555  58.225900  36.744083  26.977739
# 21       R&R     Europeana  53.228553  56.914448  39.074074  28.775295
# 22       R&R  Multilingual  52.028531  54.950052  34.705284  26.240135
# 23  R&R, BEC        German  52.723945  59.448433  35.972947  28.745889
# 24  R&R, BEC     Europeana  53.224424  56.065339  44.189011  26.520675
# 25  R&R, BEC  Multilingual  52.322548  56.522900  42.121212  25.104327
#
#     Support  Controlling     kind   Macro F1
# 1       0.0     8.039497   Strict  18.507360
# 2       0.0     3.529412   Strict  16.806131
# 3       0.0     5.600000   Strict  14.957892
# 4       0.0     9.006326   Strict  18.656828
# 5       0.0     5.365079   Strict  16.248993
# 6       0.0     8.301342   Strict  17.598407
# 7       0.0     8.742946   Strict  19.463163
# 8       0.0     8.814132   Strict  20.301001
# 9       0.0     7.857576   Strict  17.998020
# 10      0.0     5.810486   Strict  19.838631
# 11      0.0     8.750000   Strict  19.718521
# 12      0.0     6.451178   Strict  19.477291
# 14      0.0    24.811714  Relaxed  32.509368
# 15      0.0    15.860924  Relaxed  30.892446
# 16      0.0     8.672464  Relaxed  25.635903
# 17      0.0    29.472395  Relaxed  34.257963
# 18      0.0    18.727527  Relaxed  29.895986
# 19      0.0    13.040248  Relaxed  28.980745
# 20      0.0    19.934544  Relaxed  32.231304
# 21      0.0    25.154389  Relaxed  33.857793
# 22      0.0    22.443939  Relaxed  31.727990
# 23      0.0    18.676046  Relaxed  32.594543
# 24      0.0    18.678571  Relaxed  33.113003
# 25      0.0    15.084175  Relaxed  31.859194

# %%
import plotly.express as px

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Relaxed", "Strict"),
    shared_xaxes=True,
    vertical_spacing=0.05
)

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Transfer", "BERT", "Macro F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Transfer", "BERT", "Macro F1"]]

import plotly
cols = plotly.colors.DEFAULT_PLOTLY_COLORS

for i, bert in enumerate(strict_f1["BERT"].unique()):
    fig.append_trace(go.Scatter(
        x=strict_f1.query("BERT == @bert")["Transfer"],
        y=strict_f1.query("BERT == @bert")["Macro F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        name=bert,
    ), row=2, col=1)

for i, bert in enumerate(relaxed_f1["BERT"].unique()):
    fig.append_trace(go.Scatter(
        x=relaxed_f1.query("BERT == @bert")["Transfer"],
        y=relaxed_f1.query("BERT == @bert")["Macro F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        showlegend=False,
    ), row=1, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=900,
    xaxis2_title="Transfer Learning Data",
    yaxis_title="Macro F1 Score",
    yaxis2_title="Macro F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig['layout']["annotations"][0]["font"]["size"] = 20
fig['layout']["annotations"][1]["font"]["size"] = 20

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="af83ccbe-9573-4a84-ab7d-5d3eb5dc52bd" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af83ccbe-9573-4a84-ab7d-5d3eb5dc52bd")) {                    Plotly.newPlot(                        "af83ccbe-9573-4a84-ab7d-5d3eb5dc52bd",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"German","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[18.50736031266104,18.65682770808164,19.463163459608438,19.83863103614909],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Europeana","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[16.806130652465587,16.248992571101038,20.301000841262162,19.718521390088938],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)"},"name":"Multilingual","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[14.957892132119172,17.598406762301824,17.998020020398325,19.477290591420907],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[32.50936787871439,34.25796304917028,32.23130363753817,32.594543193915555],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[30.89244648225079,29.895985651547345,33.857793215989446,33.113003441939796],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)"},"showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[25.635903089132757,28.980745100219355,31.72799022512528,31.85919362870419],"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %%
fig = go.Figure()

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Transfer", "BERT", "Macro F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Transfer", "BERT", "Macro F1"]]

for i, bert in enumerate(strict_f1["BERT"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("BERT == @bert")["Transfer"],
        y=strict_f1.query("BERT == @bert")["Macro F1"],
        line=dict(width=2.5, color=cols[i]),
        marker=dict(color=cols[i], size=10),
        name=bert + " - Strict " ,
    ))

    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("BERT == @bert")["Transfer"],
        y=relaxed_f1.query("BERT == @bert")["Macro F1"],
        line=dict(width=2.5, color=cols[i], dash='dot'),
        marker=dict(color=cols[i], size=10),
        name=bert + " - Relaxed " ,
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=600,
    xaxis_title="Transfer Learning Data",
    yaxis_title="Macro F1 Score",
    # yaxis2_title="Macro F1 Score",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white",
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()

fig.write_image("arguments_comparison.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff314e95-8d8c-496e-b06e-d6b8a4874456" class="plotly-graph-div" style="height:600px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff314e95-8d8c-496e-b06e-d6b8a4874456")) {                    Plotly.newPlot(                        "ff314e95-8d8c-496e-b06e-d6b8a4874456",                        [{"line":{"color":"rgb(31, 119, 180)","width":2.5},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"German - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[18.50736031266104,18.65682770808164,19.463163459608438,19.83863103614909],"type":"scatter"},{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2.5},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"German - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[32.50936787871439,34.25796304917028,32.23130363753817,32.594543193915555],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2.5},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Europeana - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[16.806130652465587,16.248992571101038,20.301000841262162,19.718521390088938],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2.5},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Europeana - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[30.89244648225079,29.895985651547345,33.857793215989446,33.113003441939796],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","width":2.5},"marker":{"color":"rgb(44, 160, 44)","size":10},"name":"Multilingual - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[14.957892132119172,17.598406762301824,17.998020020398325,19.477290591420907],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","dash":"dot","width":2.5},"marker":{"color":"rgb(44, 160, 44)","size":10},"name":"Multilingual - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[25.635903089132757,28.980745100219355,31.72799022512528,31.85919362870419],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666, ...

# %% [markdown]
# ## Combine Trigger

# %%
from sklearn.metrics import f1_score

combined_results = []

# Baseline
baseline_metric_results = {}
metric_results_model = {}
for combine_metric in ["MCC", "accuracy"]:
    combine_metric_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["combine_trigger_results"][combine_metric] for fold in range(5)]) * 100
    combine_metric_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["combine_trigger_results"][combine_metric] for fold in range(5)]) * 100
    metric_results_model["\textbf{" + metrics_dict[combine_metric] + "}"] = f"{combine_metric_mean:.1f} ({combine_metric_std:.0f})"
        
f1_1s = []
f1_0s = []
for fold in range(5):
    trigger_res = pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["trigger_results"])

    f1_0 = f1_score(
        flatten(pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["trigger_results"])["true_combine_triggers"].to_list()),
        flatten(pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["trigger_results"])["pred_combine_triggers"].to_list()),
        pos_label=0
    )
    f1_0s.append(f1_0*100)

    f1_1 = f1_score(
        flatten(pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["trigger_results"])["true_combine_triggers"].to_list()),
        flatten(pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["trigger_results"])["pred_combine_triggers"].to_list()),
        pos_label=1
    )
    f1_1s.append(f1_1*100)

metric_results_model["\textbf{" + "\\makecell{Connected \\\\ Trigger F1}" + "}"] = f"{np.mean(f1_1s):.1f} ({np.std(f1_1s):.0f})"
metric_results_model["\textbf{" + "\\makecell{Separate \\\\ Trigger F1}" + "}"] = f"{np.mean(f1_0s):.1f} ({np.std(f1_0s):.0f})"

baseline_metric_results["Baseline"] = metric_results_model


transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for combine_metric in ["MCC", "accuracy"]:
            combine_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["combine_trigger_results"][combine_metric] for fold in range(5)]) * 100
            combine_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["combine_trigger_results"][combine_metric] for fold in range(5)]) * 100
            metric_results_model["\textbf{" + metrics_dict[combine_metric] + "}"] = f"{combine_metric_mean:.1f} ({combine_metric_std:.0f})"

        # manual computation because not done in validation...
        f1_1s = []
        f1_0s = []
        for fold in range(5):
            trigger_res = pd.DataFrame(results[model_kind]["oof_results_all"][fold]["trigger_results"])

            f1_0 = f1_score(
                flatten(pd.DataFrame(results[model_kind]["oof_results_all"][fold]["trigger_results"])["true_combine_triggers"].to_list()),
                flatten(pd.DataFrame(results[model_kind]["oof_results_all"][fold]["trigger_results"])["pred_combine_triggers"].to_list()),
                pos_label=0
            )
            f1_0s.append(f1_0*100)

            f1_1 = f1_score(
                flatten(pd.DataFrame(results[model_kind]["oof_results_all"][fold]["trigger_results"])["true_combine_triggers"].to_list()),
                flatten(pd.DataFrame(results[model_kind]["oof_results_all"][fold]["trigger_results"])["pred_combine_triggers"].to_list()),
                pos_label=1
            )
            f1_1s.append(f1_1*100)

        metric_results_model["\textbf{" + "\\makecell{Connected \\\\ Trigger F1}" + "}"] = f"{np.mean(f1_1s):.1f} ({np.std(f1_1s):.0f})"
        metric_results_model["\textbf{" + "\\makecell{Separate \\\\ Trigger F1}" + "}"] = f"{np.mean(f1_0s):.1f} ({np.std(f1_0s):.0f})"

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results.append(pd.DataFrame(baseline_metric_results).T)
combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"] ,
    "  ": combined_results.index,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)

# make largest result bold
combined_results = combined_results.apply(bold_largest, axis=0)

# add trigger result
# combined_results["\textbf{Trigger F1}"] = detect_trigger_res

# sort in order
combined_results = combined_results[["\textbf{" + metric + "}" for metric in ["MCC", "Accuracy", "\\makecell{Connected \\\\ Trigger F1}", "\\makecell{Separate \\\\ Trigger F1}"]]]
# index_df = pd.DataFrame({
#     " ": ["\makecell{Trigger\\\\Detection}"] + ["\makecell{Trigger\\\\Combination}"]*4,
#     "  ": combined_results.columns,
# })
# combined_results.columns = pd.MultiIndex.from_frame(index_df)
display(combined_results)

# convert to latex and change some things
latex_df = combined_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllll", "clcccc")
latex_df = latex_df.replace("\multicolumn{4}{l}", "\multicolumn{4}{c}")
latex_df = latex_df.replace(".0", "")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{MCC\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{MCC}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                                          \textbf{MCC}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             75.1 (5)
#                                                    \textbf{Europ.}           74.3 (5)
#                                                    \textbf{Multi.}           75.0 (7)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             77.6 (4)
#                                                    \textbf{Europ.}           76.1 (4)
#                                                    \textbf{Multi.}           77.1 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             73.4 (3)
#                                                    \textbf{Europ.}  \textbf{78.1 (2)}
#                                                    \textbf{Multi.}           73.6 (6)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             77.9 (4)
#                                                    \textbf{Europ.}           76.2 (5)
#                                                    \textbf{Multi.}           74.7 (6)
# Baseline                                           Baseline                  18.2 (5)
#
#                                                                     \textbf{Accuracy}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             87.4 (2)
#                                                    \textbf{Europ.}           87.0 (3)
#                                                    \textbf{Multi.}           87.7 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             88.8 (2)
#                                                    \textbf{Europ.}           87.7 (2)
#                                                    \textbf{Multi.}           88.7 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             86.5 (2)
#                                                    \textbf{Europ.}           88.8 (1)
#                                                    \textbf{Multi.}           86.7 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{88.9 (2)}
#                                                    \textbf{Europ.}           87.7 (3)
#                                                    \textbf{Multi.}           87.0 (3)
# Baseline                                           Baseline                  61.0 (2)
#
#                                                                    \textbf{\makecell{Connected \\ Trigger F1}}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                                      86.3 (2)
#                                                    \textbf{Europ.}                                    85.8 (3)
#                                                    \textbf{Multi.}                                    85.9 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                                      87.4 (2)
#                                                    \textbf{Europ.}                                    86.8 (2)
#                                                    \textbf{Multi.}                                    87.1 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                                      85.3 (2)
#                                                    \textbf{Europ.}                           \textbf{87.9 (2)}
#                                                    \textbf{Multi.}                                    85.5 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}                                      87.7 (2)
#                                                    \textbf{Europ.}                                    86.8 (3)
#                                                    \textbf{Multi.}                                    86.1 (3)
# Baseline                                           Baseline                                           37.0 (4)
#
#                                                                    \textbf{\makecell{Separate \\ Trigger F1}}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                                     88.3 (3)
#                                                    \textbf{Europ.}                                   87.9 (3)
#                                                    \textbf{Multi.}                                   88.9 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                            \textbf{89.9 (2)}
#                                                    \textbf{Europ.}                                   88.5 (2)
#                                                    \textbf{Multi.}                                   89.8 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                                     87.5 (1)
#                                                    \textbf{Europ.}                                   89.6 (1)
#                                                    \textbf{Multi.}                                   87.7 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}                                     89.8 (2)
#                                                    \textbf{Europ.}                                   88.4 (3)
#                                                    \textbf{Multi.}                                   87.8 (3)
# Baseline                                           Baseline                                          71.7 (3)
# \begin{tabular}{clcccc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{MCC} &  \textbf{Accuracy} & \textbf{\makecell{Connected \\ Trigger F1}} & \textbf{\makecell{Separate \\ Trigger F1}} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &           75.1 (5) &           87.4 (2) &                                    86.3 (2) &                                   88.3 (3) \\
#          & \textbf{Europ.} &           74.3 (5) &           87 (3) &                                    85.8 (3) &                                   87.9 (3) \\
#          & \textbf{Multi.} &           75 (7) &           87.7 (3) &                                    85.9 (4) &                                   88.9 (3) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           77.6 (4) &           88.8 (2) &                                    87.4 (2) &                          \textbf{89.9 (2)} \\
#          & \textbf{Europ.} &           76.1 (4) &           87.7 (2) &                                    86.8 (2) &                                   88.5 (2) \\
#          & \textbf{Multi.} &           77.1 (4) &           88.7 (2) &                                    87.1 (2) &                                   89.8 (2) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           73.4 (3) &           86.5 (2) &                                    85.3 (2) &                                   87.5 (1) \\
#          & \textbf{Europ.} &  \textbf{78.1 (2)} &           88.8 (1) &                           \textbf{87.9 (2)} &                                   89.6 (1) \\
#          & \textbf{Multi.} &           73.6 (6) &           86.7 (3) &                                    85.5 (3) &                                   87.7 (3) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &           77.9 (4) &  \textbf{88.9 (2)} &                                    87.7 (2) &                                   89.8 (2) \\
#          & \textbf{Europ.} &           76.2 (5) &           87.7 (3) &                                    86.8 (3) &                                   88.4 (3) \\
#          & \textbf{Multi.} &           74.7 (6) &           87 (3) &                                    86.1 (3) &                                   87.8 (3) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &           18.2 (5) &           61 (2) &                                    37 (4) &                                   71.7 (3) \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Type Classification

# %%
combined_results = []

# Baseline
baseline_metric_results = {}
metric_results_model = {}
for type_metric in ["MCC", "accuracy", "consequence_f1", "motivation_f1", "purpose_f1"]:
    type_metric_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
    type_metric_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
    metric_results_model["\textbf{" + metrics_dict[type_metric] + "}"] = f"{type_metric_mean:.1f} ({type_metric_std:.0f})"

baseline_metric_results["Baseline"] = metric_results_model

# Experiments
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for type_metric in ["MCC", "accuracy", "consequence_f1", "motivation_f1", "purpose_f1"]:
            type_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
            type_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
            
            metric_results_model["\textbf{" + metrics_dict[type_metric] + "}"] = f"{type_metric_mean:.1f} ({type_metric_std:.0f})"

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results.append(pd.DataFrame(baseline_metric_results).T)
combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"],
    "  ": combined_results.index,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)

# make largest result bold
combined_results = combined_results.apply(bold_largest, axis=0)

# sort in order
combined_results = combined_results[["\textbf{" + metric + "}" for metric in ["MCC", "Accuracy", "\makecell{Consequence\\\\ F1}", "\makecell{Motivation\\\\ F1}", "\makecell{Purpose\\\\ F1}"]]]
display(combined_results)

# convert to latex and change some things
latex_df = combined_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("lllllll", "clccccc")
latex_df = latex_df.replace(".0", "")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{MCC\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{MCC}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                                          \textbf{MCC}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             58.1 (9)
#                                                    \textbf{Europ.}           56.2 (6)
#                                                    \textbf{Multi.}           55.3 (8)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             57.1 (4)
#                                                    \textbf{Europ.}           56.9 (5)
#                                                    \textbf{Multi.}           50.8 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             59.6 (6)
#                                                    \textbf{Europ.}           59.2 (5)
#                                                    \textbf{Multi.}           51.0 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{59.9 (7)}
#                                                    \textbf{Europ.}           59.3 (2)
#                                                    \textbf{Multi.}           50.7 (4)
# Baseline                                           Baseline                  17.0 (4)
#
#                                                                     \textbf{Accuracy}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             73.8 (5)
#                                                    \textbf{Europ.}           72.8 (4)
#                                                    \textbf{Multi.}           72.3 (5)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             73.6 (2)
#                                                    \textbf{Europ.}           73.5 (3)
#                                                    \textbf{Multi.}           69.7 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             74.7 (4)
#                                                    \textbf{Europ.}           74.6 (3)
#                                                    \textbf{Multi.}           69.1 (2)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{75.3 (4)}
#                                                    \textbf{Europ.}           74.8 (1)
#                                                    \textbf{Multi.}           68.1 (3)
# Baseline                                           Baseline                  53.2 (2)
#
#                                                                    \textbf{\makecell{Consequence\\ F1}}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                               82.3 (6)
#                                                    \textbf{Europ.}                             81.6 (4)
#                                                    \textbf{Multi.}                             81.0 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                               82.0 (3)
#                                                    \textbf{Europ.}                             81.9 (3)
#                                                    \textbf{Multi.}                             78.4 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                               82.3 (4)
#                                                    \textbf{Europ.}                             82.2 (3)
#                                                    \textbf{Multi.}                             78.0 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}                      \textbf{82.9 (4)}
#                                                    \textbf{Europ.}                             82.3 (2)
#                                                    \textbf{Multi.}                             76.5 (5)
# Baseline                                           Baseline                                    66.8 (1)
#
#                                                                    \textbf{\makecell{Motivation\\ F1}}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                              55.2 (8)
#                                                    \textbf{Europ.}                            49.8 (5)
#                                                    \textbf{Multi.}                            52.3 (6)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                              52.8 (3)
#                                                    \textbf{Europ.}                            50.7 (5)
#                                                    \textbf{Multi.}                            46.3 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                     \textbf{57.3 (6)}
#                                                    \textbf{Europ.}                            54.4 (6)
#                                                    \textbf{Multi.}                            48.3 (5)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}                              56.2 (6)
#                                                    \textbf{Europ.}                            57.0 (5)
#                                                    \textbf{Multi.}                            51.5 (2)
# Baseline                                           Baseline                                   16.4 (7)
#
#                                                                    \textbf{\makecell{Purpose\\ F1}}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                           74.2 (6)
#                                                    \textbf{Europ.}                         76.0 (4)
#                                                    \textbf{Multi.}                         73.8 (6)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                           74.7 (6)
#                                                    \textbf{Europ.}                         75.7 (6)
#                                                    \textbf{Multi.}                         73.8 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                           76.3 (5)
#                                                    \textbf{Europ.}                \textbf{78.1 (5)}
#                                                    \textbf{Multi.}                         72.9 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}                           77.5 (6)
#                                                    \textbf{Europ.}                         76.2 (5)
#                                                    \textbf{Multi.}                         71.0 (3)
# Baseline                                           Baseline                                39.5 (5)
# \begin{tabular}{clccccc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{MCC} &  \textbf{Accuracy} & \textbf{\makecell{Consequence\\ F1}} & \textbf{\makecell{Motivation\\ F1}} & \textbf{\makecell{Purpose\\ F1}} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &           58.1 (9) &           73.8 (5) &                             82.3 (6) &                            55.2 (8) &                         74.2 (6) \\
#          & \textbf{Europ.} &           56.2 (6) &           72.8 (4) &                             81.6 (4) &                            49.8 (5) &                         76 (4) \\
#          & \textbf{Multi.} &           55.3 (8) &           72.3 (5) &                             81 (4) &                            52.3 (6) &                         73.8 (6) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           57.1 (4) &           73.6 (2) &                             82 (3) &                            52.8 (3) &                         74.7 (6) \\
#          & \textbf{Europ.} &           56.9 (5) &           73.5 (3) &                             81.9 (3) &                            50.7 (5) &                         75.7 (6) \\
#          & \textbf{Multi.} &           50.8 (4) &           69.7 (3) &                             78.4 (3) &                            46.3 (2) &                         73.8 (3) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           59.6 (6) &           74.7 (4) &                             82.3 (4) &                   \textbf{57.3 (6)} &                         76.3 (5) \\
#          & \textbf{Europ.} &           59.2 (5) &           74.6 (3) &                             82.2 (3) &                            54.4 (6) &                \textbf{78.1 (5)} \\
#          & \textbf{Multi.} &           51 (3) &           69.1 (2) &                             78 (3) &                            48.3 (5) &                         72.9 (3) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &  \textbf{59.9 (7)} &  \textbf{75.3 (4)} &                    \textbf{82.9 (4)} &                            56.2 (6) &                         77.5 (6) \\
#          & \textbf{Europ.} &           59.3 (2) &           74.8 (1) &                             82.3 (2) &                            57 (5) &                         76.2 (5) \\
#          & \textbf{Multi.} &           50.7 (4) &           68.1 (3) &                             76.5 (5) &                            51.5 (2) &                         71 (3) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &           17 (4) &           53.2 (2) &                             66.8 (1) &                            16.4 (7) &                         39.5 (5) \\
# \bottomrule
# \end{tabular}

# %%
# confusion matrix
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    type_conf_df = pd.DataFrame(
        sum(pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_results_all"][i]['classify_type_results']["confusion_matrix"]) for i in range(5)),
    )

    index_df = pd.DataFrame({
        " ": ["\multirow{3}{*}{\textbf{Predicted}}"]*3,
        "  ": ["\textbf{" + n + "}" for n in type_conf_df.index],
    })
    col_df = pd.DataFrame({
        " ": ["\textbf{Ground Truth}"]*3,
        "  ": ["\textbf{" + n + "}" for n in type_conf_df.index],
    })
    type_conf_df.columns = pd.MultiIndex.from_frame(col_df)
    type_conf_df.index = pd.MultiIndex.from_frame(index_df)

    latex_df = type_conf_df.to_latex()
    latex_df = latex_df.replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
    latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
    latex_df = latex_df.replace("\multicolumn{3}{l}", "\multicolumn{3}{c}")
    latex_df = latex_df.replace("llrrr", "llccc")


    print(tl_name)
    print(latex_df)
    print()
# Out:
# no_transfer
# \begin{tabular}{llccc}
# \toprule
#                                     &   & \multicolumn{3}{c}{\textbf{Ground Truth}} \\
#                                     &    &      \textbf{Purpose} & \textbf{Motivation} & \textbf{Consequence} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Predicted}} & \textbf{Purpose} &                   132 &                  27 &                   16 \\
#                                     & \textbf{Motivation} &                    31 &                  93 &                   50 \\
#                                     & \textbf{Consequence} &                    14 &                  45 &                  290 \\
# \bottomrule
# \end{tabular}
#
#
# dunietz
# \begin{tabular}{llccc}
# \toprule
#                                     &   & \multicolumn{3}{c}{\textbf{Ground Truth}} \\
#                                     &    &      \textbf{Purpose} & \textbf{Motivation} & \textbf{Consequence} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Predicted}} & \textbf{Purpose} &                   133 &                  28 &                   16 \\
#                                     & \textbf{Motivation} &                    25 &                  83 &                   42 \\
#                                     & \textbf{Consequence} &                    19 &                  54 &                  298 \\
# \bottomrule
# \end{tabular}
#
#
# rehbein
# \begin{tabular}{llccc}
# \toprule
#                                     &   & \multicolumn{3}{c}{\textbf{Ground Truth}} \\
#                                     &    &      \textbf{Purpose} & \textbf{Motivation} & \textbf{Consequence} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Predicted}} & \textbf{Purpose} &                   135 &                  25 &                   15 \\
#                                     & \textbf{Motivation} &                    28 &                  99 &                   54 \\
#                                     & \textbf{Consequence} &                    14 &                  41 &                  287 \\
# \bottomrule
# \end{tabular}
#
#
# rehbein_dunietz
# \begin{tabular}{llccc}
# \toprule
#                                     &   & \multicolumn{3}{c}{\textbf{Ground Truth}} \\
#                                     &    &      \textbf{Purpose} & \textbf{Motivation} & \textbf{Consequence} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Predicted}} & \textbf{Purpose} &                   132 &                  21 &                    9 \\
#                                     & \textbf{Motivation} &                    28 &                  94 &                   48 \\
#                                     & \textbf{Consequence} &                    17 &                  50 &                  299 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results = []

# Experiments
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for type_metric in ["MCC", "accuracy", "consequence_f1", "motivation_f1", "purpose_f1"]:
            type_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
            type_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["classify_type_results"][type_metric] for fold in range(5)]) * 100
            
            metric_results_model[type_metric] = type_metric_mean

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    "Transfer": flatten([[tl_name] * 3 for tl_name in ["\u2014", "BEC", "R&R", "R&R, BEC"]]),
    "BERT": ["German", "Europeana", "Multilingual"]*4,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)

# sort in order
combined_results = combined_results[[metric for metric in ["MCC", "accuracy", "consequence_f1", "motivation_f1", "purpose_f1"]]]
combined_results.columns = ["MCC", "Accuracy", "Consequence F1", "Motivation F1", "Purpose F1"]
combined_results = combined_results.reset_index()
display(combined_results)
# Out:
#     Transfer          BERT        MCC   Accuracy  Consequence F1  \
# 0          —        German  58.103017  73.845840       82.342635
# 1          —     Europeana  56.225264  72.815284       81.639359
# 2          —  Multilingual  55.322170  72.284506       81.015626
# 3        BEC        German  57.132660  73.642481       82.015890
# 4        BEC     Europeana  56.894796  73.522769       81.870106
# 5        BEC  Multilingual  50.750935  69.659153       78.399143
# 6        R&R        German  59.640316  74.712025       82.303024
# 7        R&R     Europeana  59.224353  74.582834       82.176026
# 8        R&R  Multilingual  50.980308  69.125288       78.047147
# 9   R&R, BEC        German  59.890441  75.276698       82.945876
# 10  R&R, BEC     Europeana  59.286927  74.813948       82.324036
# 11  R&R, BEC  Multilingual  50.730544  68.146881       76.506630
#
#     Motivation F1  Purpose F1
# 0       55.215067   74.237640
# 1       49.769027   76.030648
# 2       52.263534   73.758175
# 3       52.817326   74.661781
# 4       50.734034   75.682780
# 5       46.333549   73.751810
# 6       57.311122   76.280255
# 7       54.425211   78.141443
# 8       48.340538   72.938482
# 9       56.246675   77.457490
# 10      56.951743   76.198744
# 11      51.495884   71.001323

# %%
import plotly.express as px
import plotly

fig = go.Figure()

cols = plotly.colors.DEFAULT_PLOTLY_COLORS

for i, bert in enumerate(combined_results["BERT"].unique()):
    fig.add_trace(go.Scatter(
        x=combined_results.query("BERT == @bert")["Transfer"],
        y=combined_results.query("BERT == @bert")["MCC"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i], size=10),
        name=bert
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="MCC",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white",
)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()

fig.write_image("type_comparison.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="55c6cc3b-98ad-4ec8-87a5-f30794ff2eda" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55c6cc3b-98ad-4ec8-87a5-f30794ff2eda")) {                    Plotly.newPlot(                        "55c6cc3b-98ad-4ec8-87a5-f30794ff2eda",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"German","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[58.10301703091767,57.13266032251059,59.64031612723784,59.89044063434428],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Europeana","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[56.22526441240444,56.89479597316354,59.224353230224814,59.286927179525065],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)","size":10},"name":"Multilingual","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[55.3221697921946,50.75093498899928,50.98030809100318,50.730544110837904],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"h ...

# %% [markdown]
# ## Degree Results

# %%
combined_results = []

# Baseline
baseline_metric_results = {}
metric_results_model = {}
for degree_metric in ["MCC", "accuracy", "facilitate_f1", "inhibit_f1"]:
    degree_metric_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
    degree_metric_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
    metric_results_model["\textbf{" + metrics_dict[degree_metric] + "}"] = f"{degree_metric_mean:.1f} ({degree_metric_std:.0f})"

baseline_metric_results["Baseline"] = metric_results_model

# Experiments
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for degree_metric in ["MCC", "accuracy", "facilitate_f1", "inhibit_f1"]:
            degree_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
            degree_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
            
            metric_results_model["\textbf{" + metrics_dict[degree_metric] + "}"] = f"{degree_metric_mean:.1f} ({degree_metric_std:.0f})"

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results.append(pd.DataFrame(baseline_metric_results).T)
combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"],
    "  ": combined_results.index,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)

# make largest result bold
combined_results = combined_results.apply(bold_largest, axis=0)

# sort in order
combined_results = combined_results[["\textbf{" + metric + "}" for metric in ["MCC", "Accuracy", "Facilitate F1", "Inhibit F1"]]]
display(combined_results)

# convert to latex and change some things
latex_df = combined_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllll", "clcccc")
latex_df = latex_df.replace(".0", "")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{MCC\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{MCC}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                                           \textbf{MCC}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             52.7 (14)
#                                                    \textbf{Europ.}           42.9 (16)
#                                                    \textbf{Multi.}           42.1 (17)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             55.4 (15)
#                                                    \textbf{Europ.}           38.7 (12)
#                                                    \textbf{Multi.}           52.4 (12)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             64.5 (18)
#                                                    \textbf{Europ.}           58.9 (23)
#                                                    \textbf{Multi.}           46.5 (20)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{69.1 (18)}
#                                                    \textbf{Europ.}           62.8 (33)
#                                                    \textbf{Multi.}           52.5 (11)
# Baseline                                           Baseline                    0.9 (9)
#
#                                                                     \textbf{Accuracy}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             95.8 (1)
#                                                    \textbf{Europ.}           95.5 (1)
#                                                    \textbf{Multi.}           94.9 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             95.8 (2)
#                                                    \textbf{Europ.}           95.3 (1)
#                                                    \textbf{Multi.}           95.8 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             96.4 (2)
#                                                    \textbf{Europ.}           96.5 (2)
#                                                    \textbf{Multi.}           95.1 (2)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{97.0 (2)}
#                                                    \textbf{Europ.}  \textbf{97.0 (2)}
#                                                    \textbf{Multi.}           95.7 (1)
# Baseline                                           Baseline                  92.3 (2)
#
#                                                                    \textbf{Facilitate F1}  \
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}                 97.8 (1)
#                                                    \textbf{Europ.}               97.7 (0)
#                                                    \textbf{Multi.}               97.4 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}                 97.8 (1)
#                                                    \textbf{Europ.}               97.5 (0)
#                                                    \textbf{Multi.}               97.8 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}                 98.1 (1)
#                                                    \textbf{Europ.}               98.2 (1)
#                                                    \textbf{Multi.}               97.4 (1)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}        \textbf{98.4 (1)}
#                                                    \textbf{Europ.}      \textbf{98.4 (1)}
#                                                    \textbf{Multi.}               97.7 (0)
# Baseline                                           Baseline                      96.0 (1)
#
#                                                                    \textbf{Inhibit F1}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             50.4 (12)
#                                                    \textbf{Europ.}           37.7 (14)
#                                                    \textbf{Multi.}           42.7 (16)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             54.8 (14)
#                                                    \textbf{Europ.}           32.5 (13)
#                                                    \textbf{Multi.}           51.9 (13)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             65.7 (17)
#                                                    \textbf{Europ.}           57.6 (22)
#                                                    \textbf{Multi.}           45.4 (18)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}    \textbf{69.8 (17)}
#                                                    \textbf{Europ.}           62.7 (32)
#                                                    \textbf{Multi.}           52.2 (11)
# Baseline                                           Baseline                    4.0 (8)
# \begin{tabular}{clcccc}
# \toprule
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{MCC} &  \textbf{Accuracy} & \textbf{Facilitate F1} & \textbf{Inhibit F1} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &           52.7 (14) &           95.8 (1) &               97.8 (1) &           50.4 (12) \\
#          & \textbf{Europ.} &           42.9 (16) &           95.5 (1) &               97.7 (0) &           37.7 (14) \\
#          & \textbf{Multi.} &           42.1 (17) &           94.9 (2) &               97.4 (1) &           42.7 (16) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &           55.4 (15) &           95.8 (2) &               97.8 (1) &           54.8 (14) \\
#          & \textbf{Europ.} &           38.7 (12) &           95.3 (1) &               97.5 (0) &           32.5 (13) \\
#          & \textbf{Multi.} &           52.4 (12) &           95.8 (1) &               97.8 (1) &           51.9 (13) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &           64.5 (18) &           96.4 (2) &               98.1 (1) &           65.7 (17) \\
#          & \textbf{Europ.} &           58.9 (23) &           96.5 (2) &               98.2 (1) &           57.6 (22) \\
#          & \textbf{Multi.} &           46.5 (20) &           95.1 (2) &               97.4 (1) &           45.4 (18) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &  \textbf{69.1 (18)} &  \textbf{97 (2)} &      \textbf{98.4 (1)} &  \textbf{69.8 (17)} \\
#          & \textbf{Europ.} &           62.8 (33) &  \textbf{97 (2)} &      \textbf{98.4 (1)} &           62.7 (32) \\
#          & \textbf{Multi.} &           52.5 (11) &           95.7 (1) &               97.7 (0) &           52.2 (11) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &             0.9 (9) &           92.3 (2) &               96 (1) &             4 (8) \\
# \bottomrule
# \end{tabular}

# %%
# confusion matrix
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    degree_conf_df = pd.DataFrame(
        sum(pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_results_all"][i]['classify_degree_results']["confusion_matrix"]) for i in range(5)),
    )

    index_df = pd.DataFrame({
        " ": ["\multirow{2}{*}{\textbf{Predicted}}"]*2,
        "  ": ["\textbf{" + n + "}" for n in degree_conf_df.index],
    })
    col_df = pd.DataFrame({
        " ": ["\textbf{Ground Truth}"]*2,
        "  ": ["\textbf{" + n + "}" for n in degree_conf_df.index],
    })
    degree_conf_df.columns = pd.MultiIndex.from_frame(col_df)
    degree_conf_df.index = pd.MultiIndex.from_frame(index_df)

    latex_df = degree_conf_df.to_latex()
    latex_df = latex_df.replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
    latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
    latex_df = latex_df.replace("\multicolumn{2}{l}", "\multicolumn{2}{c}")

    print(tl_name)
    print(latex_df)
    print()
# Out:
# no_transfer
# \begin{tabular}{llrr}
# \toprule
#                                     &   & \multicolumn{2}{c}{\textbf{Ground Truth}} \\
#                                     &    &   \textbf{Facilitate} & \textbf{Inhibit} \\
#
# \midrule
# \multirow{2}{*}{\textbf{Predicted}} & \textbf{Facilitate} &                   654 &               24 \\
#                                     & \textbf{Inhibit} &                     5 &               15 \\
# \bottomrule
# \end{tabular}
#
#
# dunietz
# \begin{tabular}{llrr}
# \toprule
#                                     &   & \multicolumn{2}{c}{\textbf{Ground Truth}} \\
#                                     &    &   \textbf{Facilitate} & \textbf{Inhibit} \\
#
# \midrule
# \multirow{2}{*}{\textbf{Predicted}} & \textbf{Facilitate} &                   652 &               22 \\
#                                     & \textbf{Inhibit} &                     7 &               17 \\
# \bottomrule
# \end{tabular}
#
#
# rehbein
# \begin{tabular}{llrr}
# \toprule
#                                     &   & \multicolumn{2}{c}{\textbf{Ground Truth}} \\
#                                     &    &   \textbf{Facilitate} & \textbf{Inhibit} \\
#
# \midrule
# \multirow{2}{*}{\textbf{Predicted}} & \textbf{Facilitate} &                   647 &               13 \\
#                                     & \textbf{Inhibit} &                    12 &               26 \\
# \bottomrule
# \end{tabular}
#
#
# rehbein_dunietz
# \begin{tabular}{llrr}
# \toprule
#                                     &   & \multicolumn{2}{c}{\textbf{Ground Truth}} \\
#                                     &    &   \textbf{Facilitate} & \textbf{Inhibit} \\
#
# \midrule
# \multirow{2}{*}{\textbf{Predicted}} & \textbf{Facilitate} &                   653 &               15 \\
#                                     & \textbf{Inhibit} &                     6 &               24 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results = []

# Experiments
transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
for tl_name in transfer_learning_names:

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    metric_results = {}
    for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

        metric_results_model = {}
        for degree_metric in ["MCC", "accuracy", "facilitate_f1", "inhibit_f1"]:
            degree_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
            degree_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["classify_degree_results"][degree_metric] for fold in range(5)]) * 100
            
            metric_results_model[metrics_dict[degree_metric]] = degree_metric_mean

        metric_results[model_names_dict[model_kind]] = metric_results_model

    combined_results.append(pd.DataFrame(metric_results).T)

combined_results = pd.concat(combined_results)

index_df = pd.DataFrame({
    "Transfer": flatten([[tl_name] * 3 for tl_name in ["\u2014", "BEC", "R&R", "R&R, BEC"]]),
    "BERT": ["German", "Europeana", "Multilingual"]*4,
})

combined_results.index = pd.MultiIndex.from_frame(index_df)

# sort in order
combined_results = combined_results[[metric for metric in ["MCC", "Accuracy", "Facilitate F1", "Inhibit F1"]]]
combined_results = combined_results.reset_index()

display(combined_results)
# Out:
#     Transfer          BERT        MCC   Accuracy  Facilitate F1  Inhibit F1
# 0          —        German  52.650525  95.821854      97.815216   50.376068
# 1          —     Europeana  42.906329  95.537604      97.682640   37.650794
# 2          —  Multilingual  42.053704  94.947590      97.353980   42.666667
# 3        BEC        German  55.373159  95.805037      97.797500   54.794539
# 4        BEC     Europeana  38.650574  95.260705      97.538164   32.539683
# 5        BEC  Multilingual  52.400175  95.824655      97.813077   51.939394
# 6        R&R        German  64.458383  96.402517      98.095169   65.748918
# 7        R&R     Europeana  58.917214  96.542189      98.195202   57.561497
# 8        R&R  Multilingual  46.492481  95.088215      97.422969   45.434343
# 9   R&R, BEC        German  69.128754  96.960991      98.398653   69.803922
# 10  R&R, BEC     Europeana  62.830847  96.971831      98.418914   62.704354
# 11  R&R, BEC  Multilingual  52.455542  95.688380      97.740010   52.175824

# %%
fig = go.Figure()

for i, bert in enumerate(combined_results["BERT"].unique()):
    fig.add_trace(go.Scatter(
        x=combined_results.query("BERT == @bert")["Transfer"],
        y=combined_results.query("BERT == @bert")["MCC"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i], size=10),
        name=bert
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="MCC",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white",
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()

fig.write_image("degree_comparison.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a03a95ce-231a-4c02-b7e8-29039a33d92c" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a03a95ce-231a-4c02-b7e8-29039a33d92c")) {                    Plotly.newPlot(                        "a03a95ce-231a-4c02-b7e8-29039a33d92c",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"German","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[52.650525107382606,55.3731588611287,64.45838335010791,69.12875427959413],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Europeana","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[42.90632906739254,38.65057389839572,58.91721424939269,62.83084679377211],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)","size":10},"name":"Multilingual","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[42.05370356154094,52.400174513644224,46.492480613798186,52.45554232643912],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"h ...

# %% [markdown]
# ## Results matched relations

# %%
metric_kind_results = []
for metric_kind in ["strict", "relaxed"]:

    combined_results = []

    # baseline
    baseline_metric_results = {}
    metric_results_model = {}
    for match_metric in ["precision", "recall", "f1"]:
        match_metric_mean = np.mean([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
        match_metric_std = np.std([baseline_results['dbmdz/bert-base-german-cased']["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
        metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

    baseline_metric_results["Baseline"] = metric_results_model

    # experiment
    transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
    for tl_name in transfer_learning_names:

        results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results.append(pd.DataFrame(baseline_metric_results).T)
    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": flatten([[transfer_learning_names_dict[tl_name]] * 3 for tl_name in transfer_learning_names]) + ["Baseline"],
        "  ": combined_results.index,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)
    # sort in order
    combined_results = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Precision", "Recall", "F1"]]]
    metric_kind_results.append(combined_results)

metric_kind_results = pd.concat(metric_kind_results, axis=1)
metric_kind_results = metric_kind_results.T

index_df = pd.DataFrame({
    "  ": ["\textbf{Strict}"] * 3 + ["\textbf{Relaxed}"] * 3,
    " ": metric_kind_results.index,
})

metric_kind_results.index = pd.MultiIndex.from_frame(index_df)
metric_kind_results = metric_kind_results.T

# make largest result bold
metric_kind_results = metric_kind_results.apply(bold_largest, axis=0)
display(metric_kind_results)

# convert to latex and change some things
latex_df = metric_kind_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllllll", "clcccccc")
latex_df = latex_df.replace(".0", "")
latex_df = latex_df.replace("\multicolumn{3}{l}", "\multicolumn{3}{c}")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\hline\n\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Precision\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Precision}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                                       \textbf{Strict}  \
#                                                                    \textbf{Precision}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}              6.4 (1)
#                                                    \textbf{Europ.}            6.3 (1)
#                                                    \textbf{Multi.}            6.2 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}              7.7 (1)
#                                                    \textbf{Europ.}            5.9 (1)
#                                                    \textbf{Multi.}            7.2 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}              7.4 (1)
#                                                    \textbf{Europ.}   \textbf{8.9 (3)}
#                                                    \textbf{Multi.}            6.4 (1)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}              8.8 (2)
#                                                    \textbf{Europ.}            7.7 (1)
#                                                    \textbf{Multi.}            7.7 (1)
# Baseline                                           Baseline                   0.0 (0)
#
#                                                                                        \
#                                                                       \textbf{Recall}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}              8.2 (1)
#                                                    \textbf{Europ.}            7.7 (1)
#                                                    \textbf{Multi.}            8.3 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             10.0 (2)
#                                                    \textbf{Europ.}            7.2 (1)
#                                                    \textbf{Multi.}            9.5 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             11.5 (2)
#                                                    \textbf{Europ.}  \textbf{13.0 (4)}
#                                                    \textbf{Multi.}            9.8 (2)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             12.7 (3)
#                                                    \textbf{Europ.}           10.3 (2)
#                                                    \textbf{Multi.}           10.9 (2)
# Baseline                                           Baseline                   0.0 (0)
#
#                                                                                        \
#                                                                           \textbf{F1}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}              7.2 (1)
#                                                    \textbf{Europ.}            7.0 (1)
#                                                    \textbf{Multi.}            7.1 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}              8.7 (2)
#                                                    \textbf{Europ.}            6.5 (1)
#                                                    \textbf{Multi.}            8.1 (1)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}              9.0 (1)
#                                                    \textbf{Europ.}  \textbf{10.6 (4)}
#                                                    \textbf{Multi.}            7.7 (2)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             10.4 (2)
#                                                    \textbf{Europ.}            8.8 (2)
#                                                    \textbf{Multi.}            9.0 (1)
# Baseline                                           Baseline                   0.0 (0)
#
#                                                                      \textbf{Relaxed}  \
#                                                                    \textbf{Precision}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}    \textbf{60.5 (4)}
#                                                    \textbf{Europ.}           58.2 (2)
#                                                    \textbf{Multi.}           54.3 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             59.1 (3)
#                                                    \textbf{Europ.}           59.6 (2)
#                                                    \textbf{Multi.}           56.1 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             51.9 (4)
#                                                    \textbf{Europ.}           53.6 (1)
#                                                    \textbf{Multi.}           51.5 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             54.3 (1)
#                                                    \textbf{Europ.}           56.1 (3)
#                                                    \textbf{Multi.}           54.7 (3)
# Baseline                                           Baseline                  32.7 (3)
#
#                                                                                        \
#                                                                       \textbf{Recall}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}             78.0 (3)
#                                                    \textbf{Europ.}           70.8 (2)
#                                                    \textbf{Multi.}           73.9 (4)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             77.6 (3)
#                                                    \textbf{Europ.}           72.0 (5)
#                                                    \textbf{Multi.}           74.0 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             80.1 (3)
#                                                    \textbf{Europ.}           79.0 (4)
#                                                    \textbf{Multi.}           78.5 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             79.7 (3)
#                                                    \textbf{Europ.}           74.9 (4)
#                                                    \textbf{Multi.}           77.2 (5)
# Baseline                                           Baseline         \textbf{83.8 (4)}
#
#
#                                                                           \textbf{F1}
#
# \multirow{3}{*}{\makecell{---}}                    \textbf{Ger.}    \textbf{68.0 (2)}
#                                                    \textbf{Europ.}           63.8 (1)
#                                                    \textbf{Multi.}           62.4 (3)
# RULE\multirow{3}{*}{\makecell{\textbf{BEC}}}       \textbf{Ger.}             67.0 (2)
#                                                    \textbf{Europ.}           65.1 (1)
#                                                    \textbf{Multi.}           63.7 (2)
# RULE\multirow{3}{*}{\makecell{\textbf{R&R}}}       \textbf{Ger.}             62.9 (3)
#                                                    \textbf{Europ.}           63.8 (2)
#                                                    \textbf{Multi.}           62.1 (3)
# RULE\multirow{3}{*}{\textbf{\makecell{R&R, \\ B... \textbf{Ger.}             64.5 (0)
#                                                    \textbf{Europ.}           64.1 (4)
#                                                    \textbf{Multi.}           63.9 (3)
# Baseline                                           Baseline                  46.9 (2)
# \begin{tabular}{clcccccc}
# \toprule
#          &    & \multicolumn{3}{c}{\textbf{Strict}} & \multicolumn{3}{c}{\textbf{Relaxed}} \\
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} \\
#
# \midrule
# \multirow{3}{*}{\makecell{---}} & \textbf{Ger.} &            6.4 (1) &            8.2 (1) &            7.2 (1) &  \textbf{60.5 (4)} &           78 (3) &  \textbf{68 (2)} \\
#          & \textbf{Europ.} &            6.3 (1) &            7.7 (1) &            7 (1) &           58.2 (2) &           70.8 (2) &           63.8 (1) \\
#          & \textbf{Multi.} &            6.2 (2) &            8.3 (2) &            7.1 (2) &           54.3 (4) &           73.9 (4) &           62.4 (3) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{BEC}}} & \textbf{Ger.} &            7.7 (1) &           10 (2) &            8.7 (2) &           59.1 (3) &           77.6 (3) &           67 (2) \\
#          & \textbf{Europ.} &            5.9 (1) &            7.2 (1) &            6.5 (1) &           59.6 (2) &           72 (5) &           65.1 (1) \\
#          & \textbf{Multi.} &            7.2 (1) &            9.5 (1) &            8.1 (1) &           56.1 (4) &           74 (3) &           63.7 (2) \\
# \hline
# \multirow{3}{*}{\makecell{\textbf{R\&R}}} & \textbf{Ger.} &            7.4 (1) &           11.5 (2) &            9 (1) &           51.9 (4) &           80.1 (3) &           62.9 (3) \\
#          & \textbf{Europ.} &   \textbf{8.9 (3)} &  \textbf{13 (4)} &  \textbf{10.6 (4)} &           53.6 (1) &           79 (4) &           63.8 (2) \\
#          & \textbf{Multi.} &            6.4 (1) &            9.8 (2) &            7.7 (2) &           51.5 (3) &           78.5 (3) &           62.1 (3) \\
# \hline
# \multirow{3}{*}{\textbf{\makecell{R\&R, \\ BEC}}} & \textbf{Ger.} &            8.8 (2) &           12.7 (3) &           10.4 (2) &           54.3 (1) &           79.7 (3) &           64.5 (0) \\
#          & \textbf{Europ.} &            7.7 (1) &           10.3 (2) &            8.8 (2) &           56.1 (3) &           74.9 (4) &           64.1 (4) \\
#          & \textbf{Multi.} &            7.7 (1) &           10.9 (2) &            9 (1) &           54.7 (3) &           77.2 (5) &           63.9 (3) \\
# \hline
# \multicolumn{2}{c}{\textbf{Baseline}} &            0 (0) &            0 (0) &            0 (0) &           32.7 (3) &  \textbf{83.8 (4)} &           46.9 (2) \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### make plot

# %%
metric_kind_results = []
for metric_kind in ["strict", "relaxed"]:

    combined_results = []

    # experiment
    transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
    for tl_name in transfer_learning_names:

        results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased', 'dbmdz/bert-base-german-europeana-cased', 'bert-base-multilingual-cased']:

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model[metrics_dict[match_metric]] = match_metric_mean

            metric_results[model_kind] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        "Transfer": flatten([[tl_name] * 3 for tl_name in ["\u2014", "BEC", "R&R", "R&R, BEC"]]),
        "BERT": ["German", "Europeana", "Multilingual"]*4,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)
    metric_kind_results.append(combined_results)

metric_kind_results = pd.concat(metric_kind_results, axis=1)
metric_kind_results = metric_kind_results.T

index_df = pd.DataFrame({
    "Kind": ["Strict"] * 3 + ["Relaxed"] * 3,
    "Metric": metric_kind_results.index,
})

metric_kind_results.index = pd.MultiIndex.from_frame(index_df)
metric_kind_results = metric_kind_results.T

metric_kind_results
# Out:
# Kind                     Strict                          Relaxed             \
# Metric                Precision     Recall         F1  Precision     Recall
# Transfer BERT
# —        German        6.369652   8.189504   7.154313  60.529212  77.981956
#          Europeana     6.348870   7.734372   6.967698  58.167063  70.809795
#          Multilingual  6.199671   8.280840   7.074482  54.255725  73.877296
# BEC      German        7.657585  10.034580   8.672510  59.051532  77.580118
#          Europeana     5.947360   7.183153   6.490945  59.564204  72.041252
#          Multilingual  7.155599   9.482547   8.137445  56.111112  74.003301
# R&R      German        7.421696  11.490246   9.004887  51.868575  80.148352
#          Europeana     8.929016  12.997718  10.574318  53.619928  79.040531
#          Multilingual  6.361227   9.761542   7.693403  51.451666  78.540577
# R&R, BEC German        8.753766  12.733431  10.365927  54.304967  79.718223
#          Europeana     7.706352  10.268413   8.803741  56.055442  74.857952
#          Multilingual  7.731567  10.926390   9.039648  54.684345  77.213998
#
# Kind
# Metric                        F1
# Transfer BERT
# —        German        68.037232
#          Europeana     63.820719
#          Multilingual  62.412126
# BEC      German        66.967000
#          Europeana     65.058139
#          Multilingual  63.682266
# R&R      German        62.878363
#          Europeana     63.840748
#          Multilingual  62.108618
# R&R, BEC German        64.540688
#          Europeana     64.100006
#          Multilingual  63.906647

# %%
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Relaxed", "Strict"),
    shared_xaxes=True,
    vertical_spacing=0.05
)

strict_f1 = metric_kind_results["Strict"]["F1"].reset_index()
relaxed_f1 = metric_kind_results["Relaxed"]["F1"].reset_index()

for i, bert in enumerate(strict_f1["BERT"].unique()):
    fig.append_trace(go.Scatter(
        x=strict_f1.query("BERT == @bert")["Transfer"],
        y=strict_f1.query("BERT == @bert")["F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        name=bert + " - Strict "
    ), row=2, col=1)

for i, bert in enumerate(relaxed_f1["BERT"].unique()):
    fig.append_trace(go.Scatter(
        x=relaxed_f1.query("BERT == @bert")["Transfer"],
        y=relaxed_f1.query("BERT == @bert")["F1"],
        line=dict(width=2, color=cols[i], dash="dot"),
        marker=dict(color=cols[i]),
        showlegend=False,
        name=bert + " - Relaxed " ,
    ), row=1, col=1)

fig.update_layout(
    autosize=False,
    width=750,
    height=900,
    xaxis2_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    yaxis2_title="F1 Score",
    legend_title="BERT Models",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig['layout']["annotations"][0]["font"]["size"] = 20
fig['layout']["annotations"][1]["font"]["size"] = 20

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="193c5f31-be3c-426b-bc8c-c45294f33644" class="plotly-graph-div" style="height:900px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("193c5f31-be3c-426b-bc8c-c45294f33644")) {                    Plotly.newPlot(                        "193c5f31-be3c-426b-bc8c-c45294f33644",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"German - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.154312868190965,8.672510109758887,9.004887496029935,10.365927154085956],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Europeana - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[6.96769799942015,6.490944635051832,10.574318258088908,8.803740896251064],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)"},"name":"Multilingual - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.074482328923534,8.13744535354347,7.693402957039269,9.039647948644888],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"German - Relaxed ","showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[68.03723194755992,66.96700019710967,62.87836288475482,64.5406879967222],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Europeana - Relaxed ","showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[63.820718935779894,65.05813882206141,63.840748007151085,64.10000633410195],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(44, 160, 44)","dash":"dot","width":2},"marker":{"color":"rgb(44, 160, 44)"},"name":"Multilingual - Relaxed ","showlegend":false,"x":["\u2014","BEC","R&R","R&R, BEC"],"y":[62.41212583697108,63.682266045326685,62.10861814709555,63.90664690729573],"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"# ...

# %%
import plotly.express as px
import plotly
cols = plotly.colors.DEFAULT_PLOTLY_COLORS

fig = go.Figure()

strict_f1 = metric_kind_results["Strict"]["F1"].reset_index()

for i, bert in enumerate(strict_f1["BERT"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("BERT == @bert")["Transfer"],
        y=strict_f1.query("BERT == @bert")["F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        name=bert + "<br>Strict "
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()

fig.write_image("match_relation_comparison_strict.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ce953aa4-8813-4a25-a714-2a722076878a" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce953aa4-8813-4a25-a714-2a722076878a")) {                    Plotly.newPlot(                        "ce953aa4-8813-4a25-a714-2a722076878a",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"German<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.154312868190965,8.672510109758887,9.004887496029935,10.365927154085956],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Europeana<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[6.96769799942015,6.490944635051832,10.574318258088908,8.803740896251064],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","width":2},"marker":{"color":"rgb(44, 160, 44)"},"name":"Multilingual<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.074482328923534,8.13744535354347,7.693402957039269,9.039647948644888],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}]," ...

# %%
fig = go.Figure()

relaxed_f1 = metric_kind_results["Relaxed"]["F1"].reset_index()

for i, bert in enumerate(relaxed_f1["BERT"].unique()):
    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("BERT == @bert")["Transfer"],
        y=relaxed_f1.query("BERT == @bert")["F1"],
        line=dict(width=2, color=cols[i], dash="dot"),
        marker=dict(color=cols[i]),
        name=bert + "<br>Relaxed " ,
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.show()

fig.write_image("match_relation_comparison_relaxed.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8f1d7407-ec2b-4b24-adc4-5f6d2afe7425" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f1d7407-ec2b-4b24-adc4-5f6d2afe7425")) {                    Plotly.newPlot(                        "8f1d7407-ec2b-4b24-adc4-5f6d2afe7425",                        [{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"German<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[68.03723194755992,66.96700019710967,62.87836288475482,64.5406879967222],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Europeana<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[63.820718935779894,65.05813882206141,63.840748007151085,64.10000633410195],"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)","dash":"dot","width":2},"marker":{"color":"rgb(44, 160, 44)"},"name":"Multilingual<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[62.41212583697108,63.682266045326685,62.10861814709555,63.90664690729573],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26 ...

# %% [markdown]
# ## Mutliple Relations per sentence

# %%
oof_results = pd.DataFrame(results['dbmdz/bert-base-german-europeana-cased']["oof_predictions"])
is_mutliple_relation = oof_results.query("kind == 'Ground Truth'").groupby("id").count()["tokens"] > 1
mutliple_relation_ids = list(is_mutliple_relation.index[is_mutliple_relation])
oof_results["token_len"] = oof_results["tokens"].str.len()
oof_results_multiple = oof_results[oof_results["id"].isin(mutliple_relation_ids)]

oof_results_multiple
# Out:
#                                                  tokens  \
# 24    [Die, Staatsforstverwaltung, arbeitet, seit, e...
# 25    [Die, Staatsforstverwaltung, arbeitet, seit, e...
# 26    [Die, Staatsforstverwaltung, arbeitet, seit, e...
# 27    [Die, Staatsforstverwaltung, arbeitet, seit, e...
# 66    [Außer, den, genannten, verdienen, noch, die, ...
# ...                                                 ...
# 4870  [Aufnahme, von, Verti, ., Während, der, Vornah...
# 4873  [strumente, und, Belielte, zu, vermessen, sind...
# 4874  [Zur, Flächenberechnung, im, Grossen, verwende...
# 4875  [Zur, Flächenberechnung, im, Grossen, verwende...
# 4876  [Zur, Flächenberechnung, im, Grossen, verwende...
#
#                                                  labels  \
# 24    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 25    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 26    [B-Actor, I-Actor, O, O, O, O, O, O, O, B-Effe...
# 27    [B-Actor, I-Actor, O, O, O, O, O, O, O, B-Effe...
# 66    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ...                                                 ...
# 4870  [O, O, O, O, B-Cause, O, O, O, O, O, O, B-Trig...
# 4873  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4874  [B-Trigger, B-Cause, I-Cause, I-Cause, B-Trigg...
# 4875  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4876  [O, B-Cause, I-Cause, I-Cause, O, O, B-Effect,...
#
#                          kind         type      degree  relation_id    id  \
# 24                  Predicted      Purpose  Facilitate            0    65
# 25                  Predicted      Purpose  Facilitate            1    65
# 26               Ground Truth      Purpose  Facilitate            0    65
# 27               Ground Truth      Purpose  Facilitate            1    65
# 66                  Predicted  Consequence  Facilitate            0   170
# ...                       ...          ...         ...          ...   ...
# 4870  Predicted without label      Purpose  Facilitate            2  1666
# 4873  Predicted without label  Consequence  Facilitate            0  1676
# 4874  Predicted without label      Purpose  Facilitate            0  1677
# 4875  Predicted without label      Purpose  Facilitate            1  1677
# 4876  Predicted without label  Consequence  Facilitate            2  1677
#
#       fold  token_len
# 24       0         40
# 25       0         40
# 26       0         40
# 27       0         40
# 66       0         43
# ...    ...        ...
# 4870     4         87
# 4873     4         64
# 4874     4         27
# 4875     4         27
# 4876     4         27
#
# [1269 rows x 9 columns]

# %%
calc_relation_metrics(oof_results_multiple.query("type != 'None'"), config)
# Out:
# {'relaxed': {'f1': 0.7711138310893513,
#   'fn': 137,
#   'fp': 50,
#   'precision': 0.863013698630137,
#   'recall': 0.6969026548672567,
#   'tp': 315},
#  'strict': {'f1': 0.08567931456548347,
#   'fn': 417,
#   'fp': 330,
#   'precision': 0.0958904109589041,
#   'recall': 0.07743362831858407,
#   'tp': 35}}

# %%
calc_relation_metrics(oof_results.query("type != 'None'"), config)
# Out:
# {'relaxed': {'f1': 0.6417177914110429,
#   'fn': 175,
#   'fp': 409,
#   'precision': 0.5611587982832618,
#   'recall': 0.7492836676217765,
#   'tp': 523},
#  'strict': {'f1': 0.08834355828220859,
#   'fn': 626,
#   'fp': 860,
#   'precision': 0.07725321888412018,
#   'recall': 0.10315186246418338,
#   'tp': 72}}

# %% [markdown]
# ## Compare sample sentences
#
# Samples: 347

# %%
oof_results = pd.DataFrame(results['dbmdz/bert-base-german-europeana-cased']["oof_predictions"])
is_single_relation = oof_results.query("kind == 'Ground Truth'").groupby("id").count()["tokens"] == 1
single_relation_ids = list(is_single_relation.index[is_single_relation])
oof_results["token_len"] = oof_results["tokens"].str.len()
possible_ids = oof_results[oof_results["id"].isin(single_relation_ids)].query("kind == 'Ground Truth' and type != 'None' and token_len < 30")["id"].unique()

# %%
baseline_oof_results = pd.DataFrame(baseline_results['dbmdz/bert-base-german-cased']["oof_predictions"])

# %%
def connect_labels(labels):
    new_labels = [labels[0]]
    for i in range(1, len(labels)):
        
        l = labels[i]
        l_prev = labels[i-1]

        if l[2:] == l_prev[2:] and l[0] == "B":
            new_labels.append(f"I-{l[2:]}")
        else:
            new_labels.append(l)

    return new_labels

# %%
input_id = 1052

output_str = ""
for i, tl_name in enumerate(transfer_learning_names):

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    oof_results = pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_predictions"])

    sample_data = oof_results.query("id == @input_id").copy()
    baseline_sample_data = baseline_oof_results.query("id == @input_id").copy()

    sample_data["labels"] = sample_data["labels"].apply(connect_labels)
    baseline_sample_data["labels"] = baseline_sample_data["labels"].apply(connect_labels)

    if i == 0:
        gt_data = sample_data.query("kind == 'Ground Truth' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Ground<br>Truth</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data['type']}</u>, Degree: <u>{gt_data['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data["tokens"], gt_data["labels"], config)

        output_str += """</div><hr>"""


        gt_data_base = baseline_sample_data.query("kind == 'Predicted without label' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Baseline</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data_base['type']}</u>, Degree: <u>{gt_data_base['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data_base["tokens"], gt_data_base["labels"], config)

        output_str += """</div><hr>"""

        

    matches = get_matches_from_sample(sample_data, config)

    for j, match in enumerate(matches):
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Transfer Data:<br>{transfer_learning_names_dict_base[tl_name]}</h3>
        </div>"""

        output_str += f"""<div style="vertical-align:top; display: inline-block; width: 640px;">"""
        pred_rel_id = match["pred_rel_id"]
        if pred_rel_id != -1:
            pred_data = sample_data.query("kind == 'Predicted without label' & relation_id == @pred_rel_id").iloc[0]
            output_str += f"Causal Type: <u>{pred_data['type']}</u>, Degree: <u>{pred_data['degree']}</u>"
            output_str += visualize_annotated_labels(pred_data["tokens"], pred_data["labels"], config)
        else:
            output_str += get_empty_with_layout_string("Predicted")

        output_str += """</div>"""

        break

    if i != len(transfer_learning_names)-1:
        output_str += "<hr>"

for arg in config["causal_arguments"]:
    output_str = output_str.replace(f'<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">{arg}</span>', "")

# output_str = output_str.replace("padding: 0.45em 0.6em;", "")
# output_str = output_str.replace("border-radius: 0.35em;", "")
output_str = output_str.replace("padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;", "padding: 0.25em 0em;")
output_str = output_str.replace('class="entities" style="', 'class="entities" style="font-size: 1.15em;')

output_str += """
<ul class="legend">
    <li><span class="trigger"></span>Trigger</li>
    <li><span class="cause"></span>Cause</li>
    <li><span class="effect"></span>Effect</li>
    <li><span class="actor"></span>Actor</li>
    <li><span class="affected"></span>Affected</li>
    <li><span class="support"></span>Support</li>
    <li><span class="controller"></span>Controller</li>
</ul>
"""
output_str += """
<style>
    /* basic positioning */
    .legend { list-style: none; }
    .legend li { float: left; margin-right: 10px; }
    .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
    /* your colors */
    .legend .trigger { background-color: #C5E95E; }
    .legend .cause { background-color: #99FCE0; }
    .legend .effect { background-color: #6779CB; }
    .legend .actor { background-color: #108482; }
    .legend .affected { background-color: #84F72D; }
    .legend .support { background-color: #C44C6D; }
    .legend .controller { background-color: #E3AF32; }
</style>
"""

display_html(jupyter_HTML(output_str))
html = HTML(string=output_str)

css_1cm = [CSS(string="@page {height: 1cm; page-break-inside: always;}}}")]
css = [CSS(string='body { font-size: 12px; font-family: arial !important}')]
render = html.render(stylesheets=css + css_1cm)


css += [ CSS(string="@page {height: " + str(len(render.pages)-5) + "cm; margin: 0mm}}}")]
html.write_pdf("sent_example1.pdf", stylesheets=css)
# Out:
# <div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Ground<br>Truth</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     hat
#
# </mark>
#
# <mark class="entity" style="background: #E3AF32; padding: 0.25em 0em; border-radius: 0.35em;">
#     in folgenden Fällen unbedingt
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     mittelst Theodoliten
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Baseline</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     hat
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     in folgenden
#
# </mark>
#
# <mark class="entity" style="background: #E3AF32; padding: 0.25em 0em; border-radius: 0.35em;">
#     Fällen
#
# </mark>
#  unbedingt mittelst Theodoliten
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>—</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe hat
#
# </mark>
#
# <mark class="entity" style="background: #E3AF32; padding: 0.25em 0em; border-radius: 0.35em;">
#     in folgenden Fällen
#
# </mark>
#  unbedingt
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     mittelst
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     Theodoliten
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     hat
#
# </mark>
#
# <mark class="entity" style="background: #E3AF32; padding: 0.25em 0em; border-radius: 0.35em;">
#     in folgenden Fällen
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     unbedingt mittelst Theodoliten
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     hat
#
# </mark>
#  in folgenden Fällen unbedingt
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     mittelst
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     Theodoliten
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R, BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Dieselbe
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     hat
#
# </mark>
#
# <mark class="entity" style="background: #E3AF32; padding: 0.25em 0em; border-radius: 0.35em;">
#     in
#
# </mark>
#  folgenden Fällen unbedingt
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     mittelst
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     Theodoliten
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     zu erfolgen
#
# </mark>
#  :</div></div>
# <ul class="legend">
#     <li><span class="trigger"></span>Trigger</li>
#     <li><span class="cause"></span>Cause</li>
#     <li><span class="effect"></span>Effect</li>
#     <li><span class="actor"></span>Actor</li>
#     <li><span class="affected"></span>Affected</li>
#     <li><span class="support"></span>Support</li>
#     <li><span class="controller"></span>Controller</li>
# </ul>
#
# <style>
#     /* basic positioning */
#     .legend { list-style: none; }
#     .legend li { float: left; margin-right: 10px; }
#     .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
#     /* your colors */
#     .legend .trigger { background-color: #C5E95E; }
#     .legend .cause { background-color: #99FCE0; }
#     .legend .effect { background-color: #6779CB; }
#     .legend .actor { background-color: #108482; }
#     .legend .affected { background-color: #84F72D; }
#     .legend .support { background-color: #C44C6D; }
#     .legend .controller { background-color: #E3AF32; }
# </style>
# WARNING:weasyprint:Ignored `page-break-inside: always` at 1:21, invalid value.

# %%
input_id = 1649

output_str = ""
for i, tl_name in enumerate(transfer_learning_names):

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    oof_results = pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_predictions"])

    sample_data = oof_results.query("id == @input_id").copy()
    baseline_sample_data = baseline_oof_results.query("id == @input_id").copy()

    sample_data["labels"] = sample_data["labels"].apply(connect_labels)
    baseline_sample_data["labels"] = baseline_sample_data["labels"].apply(connect_labels)

    if i == 0:
        gt_data = sample_data.query("kind == 'Ground Truth' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Ground<br>Truth</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data['type']}</u>, Degree: <u>{gt_data['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data["tokens"], gt_data["labels"], config)

        output_str += """</div><hr>"""


        gt_data_base = baseline_sample_data.query("kind == 'Predicted without label' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Baseline</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data_base['type']}</u>, Degree: <u>{gt_data_base['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data_base["tokens"], gt_data_base["labels"], config)

        output_str += """</div><hr>"""

        

    matches = get_matches_from_sample(sample_data, config)

    for j, match in enumerate(matches):
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Transfer Data:<br>{transfer_learning_names_dict_base[tl_name]}</h3>
        </div>"""

        output_str += f"""<div style="vertical-align:top; display: inline-block; width: 640px;">"""
        pred_rel_id = match["pred_rel_id"]
        if pred_rel_id != -1:
            pred_data = sample_data.query("kind == 'Predicted without label' & relation_id == @pred_rel_id").iloc[0]
            output_str += f"Causal Type: <u>{pred_data['type']}</u>, Degree: <u>{pred_data['degree']}</u>"
            output_str += visualize_annotated_labels(pred_data["tokens"], pred_data["labels"], config)
        else:
            output_str += get_empty_with_layout_string("Predicted")

        output_str += """</div>"""

        break

    if i != len(transfer_learning_names)-1:
        output_str += "<hr>"

for arg in config["causal_arguments"]:
    output_str = output_str.replace(f'<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">{arg}</span>', "")

# output_str = output_str.replace("padding: 0.45em 0.6em;", "")
# output_str = output_str.replace("border-radius: 0.35em;", "")
output_str = output_str.replace("padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;", "padding: 0.25em 0em;")
output_str = output_str.replace('class="entities" style="', 'class="entities" style="font-size: 1.15em;')

output_str += """
<ul class="legend">
    <li><span class="trigger"></span>Trigger</li>
    <li><span class="cause"></span>Cause</li>
    <li><span class="effect"></span>Effect</li>
    <li><span class="actor"></span>Actor</li>
    <li><span class="affected"></span>Affected</li>
    <li><span class="support"></span>Support</li>
    <li><span class="controller"></span>Controller</li>
</ul>
"""
output_str += """
<style>
    /* basic positioning */
    .legend { list-style: none; }
    .legend li { float: left; margin-right: 10px; }
    .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
    /* your colors */
    .legend .trigger { background-color: #C5E95E; }
    .legend .cause { background-color: #99FCE0; }
    .legend .effect { background-color: #6779CB; }
    .legend .actor { background-color: #108482; }
    .legend .affected { background-color: #84F72D; }
    .legend .support { background-color: #C44C6D; }
    .legend .controller { background-color: #E3AF32; }
</style>
"""

display_html(jupyter_HTML(output_str))
html = HTML(string=output_str)

css_1cm = [CSS(string="@page {height: 1cm; page-break-inside: always;}}}")]
css = [CSS(string='body { font-size: 12px; font-family: arial !important}')]
render = html.render(stylesheets=css + css_1cm)


css += [ CSS(string="@page {height: " + str(len(render.pages)-5) + "cm; margin: 0mm}}}")]
html.write_pdf("sent_example2.pdf", stylesheets=css)
# Out:
# <div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Ground<br>Truth</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>Motivation</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #84F72D; padding: 0.25em 0em; border-radius: 0.35em;">
#     Im Ausschlagwalde
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Altersunterschiede von 5 zu 5 Jahren
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     für die Bestandestrennung
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Baseline</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>Consequence</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">Im Ausschlagwalde sind Altersunterschiede von 5 zu 5 Jahren
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     für
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     die
#
# </mark>
#  Bestandestrennung
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>—</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Consequence</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">Im Ausschlagwalde
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Altersunterschiede von 5 zu 5 Jahren
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     für
#
# </mark>
#  die Bestandestrennung
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Consequence</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #84F72D; padding: 0.25em 0em; border-radius: 0.35em;">
#     Im Ausschlagwalde
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Altersunterschiede von 5 zu 5 Jahren
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     für die Bestandestrennung
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Consequence</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">Im Ausschlagwalde
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Altersunterschiede von 5 zu 5 Jahren
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     für die Bestandestrennung
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R, BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Motivation</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">Im Ausschlagwalde
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     Altersunterschiede von 5 zu 5 Jahren
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     für die Bestandestrennung
#
# </mark>
#
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     massgebend
#
# </mark>
#  .</div></div>
# <ul class="legend">
#     <li><span class="trigger"></span>Trigger</li>
#     <li><span class="cause"></span>Cause</li>
#     <li><span class="effect"></span>Effect</li>
#     <li><span class="actor"></span>Actor</li>
#     <li><span class="affected"></span>Affected</li>
#     <li><span class="support"></span>Support</li>
#     <li><span class="controller"></span>Controller</li>
# </ul>
#
# <style>
#     /* basic positioning */
#     .legend { list-style: none; }
#     .legend li { float: left; margin-right: 10px; }
#     .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
#     /* your colors */
#     .legend .trigger { background-color: #C5E95E; }
#     .legend .cause { background-color: #99FCE0; }
#     .legend .effect { background-color: #6779CB; }
#     .legend .actor { background-color: #108482; }
#     .legend .affected { background-color: #84F72D; }
#     .legend .support { background-color: #C44C6D; }
#     .legend .controller { background-color: #E3AF32; }
# </style>
# WARNING:weasyprint:Ignored `page-break-inside: always` at 1:21, invalid value.

# %%
input_id = 916

output_str = ""
for i, tl_name in enumerate(transfer_learning_names):

    results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{tl_name}.json"

    with open(results_path, "r") as f:
        results = json.load(f)

    oof_results = pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_predictions"])

    sample_data = oof_results.query("id == @input_id").copy()
    baseline_sample_data = baseline_oof_results.query("id == @input_id").copy()

    sample_data["labels"] = sample_data["labels"].apply(connect_labels)
    baseline_sample_data["labels"] = baseline_sample_data["labels"].apply(connect_labels)

    if i == 0:
        gt_data = sample_data.query("kind == 'Ground Truth' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Ground<br>Truth</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data['type']}</u>, Degree: <u>{gt_data['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data["tokens"], gt_data["labels"], config)

        output_str += """</div><hr>"""


        gt_data_base = baseline_sample_data.query("kind == 'Predicted without label' & relation_id == 0").iloc[0]
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Baseline</h3>
        </div>"""
        output_str += """<div style="vertical-align:top; display: inline-block; width: 640px">"""

        output_str += f"Causal Type: <u>{gt_data_base['type']}</u>, Degree: <u>{gt_data_base['degree']}</u>"
        output_str += visualize_annotated_labels(gt_data_base["tokens"], gt_data_base["labels"], config)

        output_str += """</div><hr>"""

        

    matches = get_matches_from_sample(sample_data, config)

    for j, match in enumerate(matches):
        output_str += f"""<div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
            <h3>Transfer Data:<br>{transfer_learning_names_dict_base[tl_name]}</h3>
        </div>"""

        output_str += f"""<div style="vertical-align:top; display: inline-block; width: 640px;">"""
        pred_rel_id = match["pred_rel_id"]
        if pred_rel_id != -1:
            pred_data = sample_data.query("kind == 'Predicted without label' & relation_id == @pred_rel_id").iloc[0]
            output_str += f"Causal Type: <u>{pred_data['type']}</u>, Degree: <u>{pred_data['degree']}</u>"
            output_str += visualize_annotated_labels(pred_data["tokens"], pred_data["labels"], config)
        else:
            output_str += get_empty_with_layout_string("Predicted")

        output_str += """</div>"""

        break

    if i != len(transfer_learning_names)-1:
        output_str += "<hr>"

for arg in config["causal_arguments"]:
    output_str = output_str.replace(f'<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">{arg}</span>', "")

# output_str = output_str.replace("padding: 0.45em 0.6em;", "")
# output_str = output_str.replace("border-radius: 0.35em;", "")
output_str = output_str.replace("padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;", "padding: 0.25em 0em;")
output_str = output_str.replace('class="entities" style="', 'class="entities" style="font-size: 1.15em;')

output_str += """
<ul class="legend">
    <li><span class="trigger"></span>Trigger</li>
    <li><span class="cause"></span>Cause</li>
    <li><span class="effect"></span>Effect</li>
    <li><span class="actor"></span>Actor</li>
    <li><span class="affected"></span>Affected</li>
    <li><span class="support"></span>Support</li>
    <li><span class="controller"></span>Controller</li>
</ul>
"""
output_str += """
<style>
    /* basic positioning */
    .legend { list-style: none; }
    .legend li { float: left; margin-right: 10px; }
    .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
    /* your colors */
    .legend .trigger { background-color: #C5E95E; }
    .legend .cause { background-color: #99FCE0; }
    .legend .effect { background-color: #6779CB; }
    .legend .actor { background-color: #108482; }
    .legend .affected { background-color: #84F72D; }
    .legend .support { background-color: #C44C6D; }
    .legend .controller { background-color: #E3AF32; }
</style>
"""

display_html(jupyter_HTML(output_str))
html = HTML(string=output_str)

css_1cm = [CSS(string="@page {height: 1cm; page-break-inside: always;}}}")]
css = [CSS(string='body { font-size: 12px; font-family: arial !important}')]
render = html.render(stylesheets=css + css_1cm)


css += [ CSS(string="@page {height: " + str(len(render.pages)-5) + "cm; margin: 0mm}}}")]
html.write_pdf("sent_example3.pdf", stylesheets=css)
# Out:
# <div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Ground<br>Truth</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>None</u>, Degree: <u>None</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">Zur grösseren Deutlichkeit sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe auf weissem Grunde ersichtlich gemacht worden .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Baseline</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     Zur
#
# </mark>
#  grösseren Deutlichkeit
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind
#
# </mark>
#  auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe auf weissem Grunde ersichtlich gemacht worden .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>—</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     Zur
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     grösseren Deutlichkeit
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe auf weissem Grunde ersichtlich gemacht worden
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     Zur
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     grösseren Deutlichkeit
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe auf weissem Grunde ersichtlich gemacht worden
#
# </mark>
#  .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     Zur
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     grösseren Deutlichkeit
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe
#
# </mark>
#  auf weissem Grunde ersichtlich gemacht worden .</div></div><hr><div style="vertical-align:top; display: inline-block; width:120px; text-align: center;">
#             <h3>Transfer Data:<br>R&R, BEC</h3>
#         </div><div style="vertical-align:top; display: inline-block; width: 640px;">Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="font-size: 1.15em;line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.25em 0em; border-radius: 0.35em;">
#     Zur
#
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.25em 0em; border-radius: 0.35em;">
#     grösseren Deutlichkeit
#
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.25em 0em; border-radius: 0.35em;">
#     sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe
#
# </mark>
#  auf weissem Grunde ersichtlich gemacht worden .</div></div>
# <ul class="legend">
#     <li><span class="trigger"></span>Trigger</li>
#     <li><span class="cause"></span>Cause</li>
#     <li><span class="effect"></span>Effect</li>
#     <li><span class="actor"></span>Actor</li>
#     <li><span class="affected"></span>Affected</li>
#     <li><span class="support"></span>Support</li>
#     <li><span class="controller"></span>Controller</li>
# </ul>
#
# <style>
#     /* basic positioning */
#     .legend { list-style: none; }
#     .legend li { float: left; margin-right: 10px; }
#     .legend span { border: 1px solid #ccc; float: left; width: 12px; height: 12px; margin: 2px; }
#     /* your colors */
#     .legend .trigger { background-color: #C5E95E; }
#     .legend .cause { background-color: #99FCE0; }
#     .legend .effect { background-color: #6779CB; }
#     .legend .actor { background-color: #108482; }
#     .legend .affected { background-color: #84F72D; }
#     .legend .support { background-color: #C44C6D; }
#     .legend .controller { background-color: #E3AF32; }
# </style>
# WARNING:weasyprint:Ignored `page-break-inside: always` at 1:21, invalid value.

# %% [markdown]
# # Visualize all Results

# %%
results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_{transfer_learning_names[-1]}.json"

with open(results_path, "r") as f:
    results = json.load(f)

oof_results = pd.DataFrame(results['dbmdz/bert-base-german-cased']["oof_predictions"])

# %%
output = "<h1> Fondsforste Prediction Quality Check <h1>"

for id in [916]: #tqdm(sorted(oof_results["id"].unique()[:])):

    # no relation in GT or predicted
    sample_data = oof_results.query("id == @id")
    if len(sample_data["type"].unique()) == 1 and sample_data["type"].unique()[0] == "None":
        continue

    # if len(sample_data["tokens"].iloc[0]) > 30: continue


    output += visualize_id_html(id, oof_results, config)

display_html(jupyter_HTML(output))
# Out:
# <h1> Fondsforste Prediction Quality Check <h1><h2>Sample 916</h2><h3>Relation <u>0</u> with score: <u>0.000</u></h3><h4>Ground Truth</h4>Causal Type: <u>None</u>, Degree: <u>None</u><div class="entities" style="line-height: 2.5; direction: ltr">Zur grösseren Deutlichkeit sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe auf weissem Grunde ersichtlich gemacht worden .</div><h4>Predicted</h4>Causal Type: <u>Purpose</u>, Degree: <u>Facilitate</u><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #C5E95E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Trigger</span>
# </mark>
#
# <mark class="entity" style="background: #99FCE0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     grösseren Deutlichkeit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Cause</span>
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und mit schwarzer Farbe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Effect</span>
# </mark>
#  auf weissem Grunde ersichtlich gemacht worden .</div><h3>Relation <u>1</u> with score: <u>0.000</u></h3><h4>Ground Truth</h4><b><i>No match found</i></b><h4>Predicted</h4>Causal Type: <u>Motivation</u>, Degree: <u>Facilitate</u><div class="entities" style="line-height: 2.5; direction: ltr">Zur grösseren Deutlichkeit sind auf den Grenzsteinen die Nummern und Buchstaben eingehauen und
# <mark class="entity" style="background: #6779CB; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mit schwarzer Farbe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Effect</span>
# </mark>
#
# <mark class="entity" style="background: #C44C6D; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     auf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Support</span>
# </mark>
#  weissem
# <mark class="entity" style="background: #C5E95E; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grunde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Trigger</span>
# </mark>
#
# <mark class="entity" style="background: #6779CB; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ersichtlich gemacht
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Effect</span>
# </mark>
#  worden .</div><hr>

# %%
oof_results.query("id == 398")
# Out:
#      tokens labels          kind  type degree  relation_id   id  fold
# 1177     []     []  Ground Truth  None   None            0  398     1
# 1178     []     []     Predicted  None   None            0  398     1

# %%
html = HTML(string=output)
css = CSS(
    string="font: serif"
)

# datetime apparently 2 hours behind?
html.write_pdf("forstvermessung_predictions_v1-2.pdf", stylesheets=[CSS(string='body { font-size: 10px; font-family: arial !important }')])

# %% [markdown]
# # Evaluate Normalization

# %% [markdown]
# ## Arguments

# %%
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [norm_time, norm_name]]:

        results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_rehbein_dunietz.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased']:

            metric_results_model = {}
            trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            metric_results_model["\textbf{" + "Trigger" + "}"] = f"{trigger_mean:.1f} ({trigger_std:.0f})"

            for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                
                if c_arg == "Controlling": c_arg = "Contr."
                if c_arg == "Affected": c_arg = "Aff."
                if c_arg == "Support": c_arg = "Sup."
                metric_results_model["\textbf{" + c_arg + "}"] = f"{c_arg_mean:.1f} ({c_arg_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": ["\multirow{3}{*}{\textbf{Original}}"] * 1 + ["RULE\multirow{3}{*}{\textbf{Normalization}}"] * 1,
        "  ": combined_results.index,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    # make largest result bold
    combined_results = combined_results.apply(bold_largest, axis=0)

    combined_results_sub = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Trigger", "Cause", "Effect", "Actor", "Aff.", "Sup.", "Contr."]]]
    display(combined_results_sub)

    # convert to latex and change some things
    latex_df = combined_results_sub.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
    latex_df = latex_df.replace("RULE", "\hline\n")
    latex_df = latex_df.replace("lllllllll", "clccccccc")
    latex_df = latex_df.replace(".0", "") 
    latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Trigger\}", r"\\textbf{\\makecell{Pre-processing}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Trigger}", latex_df, flags=re.MULTILINE)
    print(metric_kind)
    print(latex_df)
# Out:
#                                                             \textbf{Trigger}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           49.2 (2)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{50.9 (1)}
#
#                                                               \textbf{Cause}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           28.7 (2)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{29.6 (3)}
#
#                                                              \textbf{Effect}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}  \textbf{31.0 (5)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}           29.8 (4)
#
#                                                               \textbf{Actor}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}          33.0 (13)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{35.4 (9)}
#
#                                                                \textbf{Aff.}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           20.5 (6)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{21.8 (4)}
#
#                                                           \textbf{Sup.}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}       0.0 (0)
#
#                                                             \textbf{Contr.}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           5.8 (5)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{7.3 (5)}
# strict
# \begin{tabular}{clccccccc}
# \toprule
# \textbf{\makecell{Pre-processing}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Trigger} &     \textbf{Cause} &    \textbf{Effect} &     \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &   \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &           49.2 (2) &           28.7 (2) &  \textbf{31 (5)} &          33 (13) &           20.5 (6) &       0 (0) &           5.8 (5) \\
# \hline
# \multirow{3}{*}{\textbf{Normalization}} & \textbf{Ger.} &  \textbf{50.9 (1)} &  \textbf{29.6 (3)} &           29.8 (4) &  \textbf{35.4 (9)} &  \textbf{21.8 (4)} &       0 (0) &  \textbf{7.3 (5)} \\
# \bottomrule
# \end{tabular}
#                                                             \textbf{Trigger}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           49.2 (2)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{50.9 (1)}
#
#                                                               \textbf{Cause}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           52.7 (2)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{53.9 (4)}
#
#                                                              \textbf{Effect}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}  \textbf{59.4 (3)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}           58.9 (3)
#
#                                                                \textbf{Actor}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           36.0 (13)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{38.3 (12)}
#
#                                                                \textbf{Aff.}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}  \textbf{28.7 (8)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}           27.8 (6)
#
#                                                           \textbf{Sup.}  \
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}       0.0 (0)
#
#                                                              \textbf{Contr.}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           18.7 (3)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{23.0 (5)}
# relaxed
# \begin{tabular}{clccccccc}
# \toprule
# \textbf{\makecell{Pre-processing}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Trigger} &     \textbf{Cause} &    \textbf{Effect} &      \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &    \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &           49.2 (2) &           52.7 (2) &  \textbf{59.4 (3)} &           36 (13) &  \textbf{28.7 (8)} &       0 (0) &           18.7 (3) \\
# \hline
# \multirow{3}{*}{\textbf{Normalization}} & \textbf{Ger.} &  \textbf{50.9 (1)} &  \textbf{53.9 (4)} &           58.9 (3) &  \textbf{38.3 (12)} &           27.8 (6) &       0 (0) &  \textbf{23 (5)} \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results_all = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [norm_time, norm_name]]:

        transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
        for tl_name in transfer_learning_names:
            results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_{tl_name}.json"

            with open(results_path, "r") as f:
                results = json.load(f)

            metric_results = {}
            for model_kind in ['dbmdz/bert-base-german-cased']:

                metric_results_model = {}
                trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
                trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
                metric_results_model["Trigger"] = trigger_mean

                for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                    c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                    c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                    
                    metric_results_model[c_arg] = c_arg_mean

                metric_results[tl_name] = metric_results_model

            combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results, axis=0)

    index_df = pd.DataFrame({
        "Preprocessing": ["Original"]*4 + ["Normalization"]*4,
        "Transfer": ["\u2014", "BEC", "R&R", "R&R, BEC"]*2,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    combined_results_sub = combined_results[[c_arg for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]]]
    combined_results_sub["kind"] = metric_kind.title()

    combined_results_all.append(combined_results_sub)

combined_results_all = pd.concat(combined_results_all, axis=0).reset_index()
combined_results_all["Macro F1"] = combined_results_all[["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]].mean(axis=1)
combined_results_all
# Out:
#     Preprocessing  Transfer      Cause     Effect      Actor   Affected  \
# 0        Original         —  25.555826  24.743564  32.740436  19.964839
# 1        Original       BEC  27.306735  25.814670  29.592922  20.220313
# 2        Original       R&R  26.389672  29.764783  31.306295  20.575285
# 3        Original  R&R, BEC  28.687005  31.025641  33.039614  20.469040
# 4   Normalization         —  26.092504  23.801175  30.600733  19.558196
# 5   Normalization       BEC  26.330017  25.372231  32.826236  18.913373
# 6   Normalization       R&R  28.484691  29.678244  31.996537  19.936011
# 7   Normalization  R&R, BEC  29.622923  29.842456  35.359408  21.811150
# 8        Original         —  49.550221  52.690052  44.521596  23.482625
# 9        Original       BEC  51.525570  54.763312  42.583226  27.203276
# 10       Original       R&R  51.505555  58.225900  36.744083  26.977739
# 11       Original  R&R, BEC  52.723945  59.448433  35.972947  28.745889
# 12  Normalization         —  50.441239  52.389762  36.596337  25.739104
# 13  Normalization       BEC  51.919834  55.196464  37.422509  26.121119
# 14  Normalization       R&R  51.224476  57.510828  39.300433  35.472163
# 15  Normalization  R&R, BEC  53.885476  58.877432  38.320447  27.847073
#
#     Support  Controlling     kind   Macro F1
# 0       0.0     8.039497   Strict  18.507360
# 1       0.0     9.006326   Strict  18.656828
# 2       0.0     8.742946   Strict  19.463163
# 3       0.0     5.810486   Strict  19.838631
# 4       0.0     6.906832   Strict  17.826573
# 5       0.0     6.145455   Strict  18.264552
# 6       0.0     9.312787   Strict  19.901378
# 7       0.0     7.276936   Strict  20.652145
# 8       0.0    24.811714  Relaxed  32.509368
# 9       0.0    29.472395  Relaxed  34.257963
# 10      0.0    19.934544  Relaxed  32.231304
# 11      0.0    18.676046  Relaxed  32.594543
# 12      0.0    27.465416  Relaxed  32.105310
# 13      0.0    27.782243  Relaxed  33.073695
# 14      0.0    22.117370  Relaxed  34.270878
# 15      0.0    22.997475  Relaxed  33.654651

# %%
import plotly.express as px

fig = go.Figure()

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Preprocessing", "Transfer", "Macro F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "Macro F1"]]

import plotly
cols = plotly.colors.DEFAULT_PLOTLY_COLORS

for i, pre in enumerate(strict_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("Preprocessing == @pre")["Transfer"],
        y=strict_f1.query("Preprocessing == @pre")["Macro F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(
            color=cols[i],
            size=10,
        ),        
        name=pre + " - Strict " ,
    ))

    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("Preprocessing == @pre")["Transfer"],
        y=relaxed_f1.query("Preprocessing == @pre")["Macro F1"],
        line=dict(width=2, color=cols[i], dash='dot'),
        marker=dict(
            color=cols[i],
            size=10,
        ),
        name=pre + " - Relaxed " ,
    ))

fig.update_layout(
    autosize=False,
    width=1200,
    height=600,
    xaxis_title="Transfer Learning Data",
    yaxis_title="Macro F1 Score",
    # yaxis2_title="Macro F1 Score",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white",
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#292828')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#292828')

fig.show()

fig.write_image("arguments_normalization_comp.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6a7359a0-1858-42fb-90e3-523bc5766dd3" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a7359a0-1858-42fb-90e3-523bc5766dd3")) {                    Plotly.newPlot(                        "6a7359a0-1858-42fb-90e3-523bc5766dd3",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"Original - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[18.50736031266104,18.65682770808164,19.463163459608438,19.83863103614909],"type":"scatter"},{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"Original - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[32.50936787871439,34.25796304917028,32.23130363753817,32.594543193915555],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Normalization - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[17.826573436358085,18.264551823407647,19.90137821024637,20.65214535409648],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Normalization - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[32.10530955900041,33.07369478255861,34.270878372621254,33.654650566598505],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# ## Matched Relations

# %%
metric_kind_results = []
for metric_kind in ["strict", "relaxed"]:

    combined_results = []

    # experiment
    for t, n in [[time, name], [norm_time, norm_name]]:

        results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_rehbein_dunietz.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased']:

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": ["\multirow{3}{*}{\textbf{Original}}"] * 1 + ["RULE\multirow{3}{*}{\textbf{Normalization}}"] * 1,
        "  ": combined_results.index,
    })


    combined_results.index = pd.MultiIndex.from_frame(index_df)
    # sort in order
    combined_results = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Precision", "Recall", "F1"]]]
    metric_kind_results.append(combined_results)

metric_kind_results = pd.concat(metric_kind_results, axis=1)
metric_kind_results = metric_kind_results.T

index_df = pd.DataFrame({
    "  ": ["\textbf{Strict}"] * 3 + ["\textbf{Relaxed}"] * 3,
    " ": metric_kind_results.index,
})

metric_kind_results.index = pd.MultiIndex.from_frame(index_df)
metric_kind_results = metric_kind_results.T

# make largest result bold
metric_kind_results = metric_kind_results.apply(bold_largest, axis=0)
display(metric_kind_results)

# convert to latex and change some things
latex_df = metric_kind_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllllll", "clcccccc")
latex_df = latex_df.replace(".0", "")
latex_df = latex_df.replace("\multicolumn{3}{l}", "\multicolumn{3}{c}")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Precision\}", r"\\textbf{\\makecell{Transfer \\\\ Learning}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Precision}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                              \textbf{Strict}  \
#                                                           \textbf{Precision}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}   \textbf{8.8 (2)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}            8.4 (1)
#
#                                                                               \
#                                                              \textbf{Recall}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}  \textbf{12.7 (3)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}           12.3 (1)
#
#                                                                               \
#                                                                  \textbf{F1}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}  \textbf{10.4 (2)}
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}           10.0 (1)
#
#                                                             \textbf{Relaxed}  \
#                                                           \textbf{Precision}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           54.3 (1)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{54.7 (2)}
#
#                                                                               \
#                                                              \textbf{Recall}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           79.7 (3)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{80.1 (1)}
#
#
#                                                                  \textbf{F1}
#
# \multirow{3}{*}{\textbf{Original}}          \textbf{Ger.}           64.5 (0)
# RULE\multirow{3}{*}{\textbf{Normalization}} \textbf{Ger.}  \textbf{65.0 (1)}
# \begin{tabular}{clcccccc}
# \toprule
#                                             &    & \multicolumn{3}{c}{\textbf{Strict}} & \multicolumn{3}{c}{\textbf{Relaxed}} \\
# \textbf{\makecell{Transfer \\ Learning}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &   \textbf{8.8 (2)} &  \textbf{12.7 (3)} &  \textbf{10.4 (2)} &           54.3 (1) &           79.7 (3) &           64.5 (0) \\
# \hline
# \multirow{3}{*}{\textbf{Normalization}} & \textbf{Ger.} &            8.4 (1) &           12.3 (1) &           10 (1) &  \textbf{54.7 (2)} &  \textbf{80.1 (1)} &  \textbf{65 (1)} \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results_all = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [norm_time, norm_name]]:

        # experiment
        transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
        for tl_name in transfer_learning_names:

            results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_{tl_name}.json"

            with open(results_path, "r") as f:
                results = json.load(f)

            metric_results = {}
            model_kind = 'dbmdz/bert-base-german-cased'

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model[metrics_dict[match_metric]] = match_metric_mean
                metric_results_model["Preprocessing"] = n
                metric_results_model["Transfer"] = transfer_learning_names_dict_base[tl_name]
                metric_results_model["kind"] = metric_kind.title()

            metric_results[model_kind] = metric_results_model

            combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)
    combined_results_all.append(combined_results)

combined_results_all = pd.concat(combined_results_all, axis=0).reset_index()

combined_results_all
# Out:
#                            index         F1  Precision  Preprocessing  \
# 0   dbmdz/bert-base-german-cased   7.154313   6.369652   normal_valid
# 1   dbmdz/bert-base-german-cased    8.67251   7.657585   normal_valid
# 2   dbmdz/bert-base-german-cased   9.004887   7.421696   normal_valid
# 3   dbmdz/bert-base-german-cased  10.365927   8.753766   normal_valid
# 4   dbmdz/bert-base-german-cased   8.943326   7.882818  normalization
# 5   dbmdz/bert-base-german-cased   9.049178   7.992814  normalization
# 6   dbmdz/bert-base-german-cased   9.709657   7.974674  normalization
# 7   dbmdz/bert-base-german-cased   9.997281   8.408707  normalization
# 8   dbmdz/bert-base-german-cased  68.037232  60.529212   normal_valid
# 9   dbmdz/bert-base-german-cased     66.967  59.051532   normal_valid
# 10  dbmdz/bert-base-german-cased  62.878363  51.868575   normal_valid
# 11  dbmdz/bert-base-german-cased  64.540688  54.304967   normal_valid
# 12  dbmdz/bert-base-german-cased  67.161817  58.731196  normalization
# 13  dbmdz/bert-base-german-cased  65.415713  57.939398  normalization
# 14  dbmdz/bert-base-german-cased  62.988925  51.827112  normalization
# 15  dbmdz/bert-base-german-cased  64.987296  54.700439  normalization
#
#        Recall  Transfer     kind
# 0    8.189504         —   Strict
# 1    10.03458       BEC   Strict
# 2   11.490246       R&R   Strict
# 3   12.733431  R&R, BEC   Strict
# 4   10.424318         —   Strict
# 5   10.473233       BEC   Strict
# 6   12.451503       R&R   Strict
# 7   12.334364  R&R, BEC   Strict
# 8   77.981956         —  Relaxed
# 9   77.580118       BEC  Relaxed
# 10  80.148352       R&R  Relaxed
# 11  79.718223  R&R, BEC  Relaxed
# 12  79.039387         —  Relaxed
# 13  75.425071       BEC  Relaxed
# 14  80.573926       R&R  Relaxed
# 15  80.097671  R&R, BEC  Relaxed

# %%
import plotly.express as px

fig = make_subplots(
    rows=2, cols=1,
    # subplot_titles=("Strict", "Relaxed"),
    subplot_titles=(" ", " "),
    shared_xaxes=True,
    vertical_spacing=0.05
)

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Preprocessing", "Transfer", "F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "F1"]]

fig = go.Figure()

preprocess_dict = {
    "normal_valid": "Original",
    "normalization": "Normalized",
}
for i, pre in enumerate(strict_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("Preprocessing == @pre")["Transfer"],
        y=strict_f1.query("Preprocessing == @pre")["F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        name=preprocess_dict[pre] + "<br>Strict "
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()

fig.write_image("matched_rel_norm_comb_strict.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8600474b-d744-4925-bfa9-1b5a0fd9acae" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8600474b-d744-4925-bfa9-1b5a0fd9acae")) {                    Plotly.newPlot(                        "8600474b-d744-4925-bfa9-1b5a0fd9acae",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"Original<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.154312868190965,8.672510109758887,9.004887496029935,10.365927154085956],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Normalized<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[8.943326074474614,9.049177559339086,9.709656859151025,9.997281328253923],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"par ...

# %%
import plotly.express as px

fig = make_subplots(
    rows=2, cols=1,
    # subplot_titles=("Strict", "Relaxed"),
    subplot_titles=(" ", " "),
    shared_xaxes=True,
    vertical_spacing=0.05
)

relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "F1"]]

fig = go.Figure()

preprocess_dict = {
    "normal_valid": "Original",
    "normalization": "Normalized",
}
for i, pre in enumerate(relaxed_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("Preprocessing == @pre")["Transfer"],
        y=relaxed_f1.query("Preprocessing == @pre")["F1"],
        line=dict(width=2, color=cols[i], dash="dot"),
        marker=dict(color=cols[i]),
        name=preprocess_dict[pre] + "<br>Relaxed "
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()

fig.write_image("matched_rel_norm_comb_relaxed.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f97a0755-f944-4d20-b0e9-bca97d3a81eb" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f97a0755-f944-4d20-b0e9-bca97d3a81eb")) {                    Plotly.newPlot(                        "f97a0755-f944-4d20-b0e9-bca97d3a81eb",                        [{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"Original<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[68.03723194755992,66.96700019710967,62.87836288475482,64.5406879967222],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Normalized<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[67.16181703052368,65.41571293157051,62.988925105381924,64.9872956586955],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# ## Sanity Check

# %%
# normal results
results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_rehbein_dunietz.json"

with open(results_path, "r") as f:
    results= json.load(f)

oof_results = pd.DataFrame(results["dbmdz/bert-base-german-cased"]["oof_predictions"]).query("kind != 'Predicted without label'").drop_duplicates("id")
display(oof_results)


# norm results
results_path_norm = PROJECT_PATH + f"output/{norm_time}_{norm_name}/"  + f"{corpus_name}_predictions_{norm_time}_rehbein_dunietz.json"

with open(results_path_norm, "r") as f:
    results_norm = json.load(f)

oof_results_norm = pd.DataFrame(results_norm["dbmdz/bert-base-german-cased"]["oof_predictions"]).query("kind != 'Predicted without label'").drop_duplicates("id")
oof_results_norm
# Out:
#                                                  tokens  \
# 0     [[, Datei, :, /media, /, bernhard, /, 40FE-DE2...
# 2     [Während, der, beherzte, Weidmann, im, Osten, ...
# 4     [In, diesem, Wechsel, der, Verhältnisse, sind,...
# 6     [Die, in, Verwaltung, des, Ackerbauministerium...
# 8     [Die, Ursachen, dieser, Erscheinung, sind, ein...
# ...                                                 ...
# 4759  [Zur, Flächenberechnung, im, Grossen, verwende...
# 4765  [Die, Flächen-Grössen, sind, in, der, zugehöri...
# 4767                                            [VI, .]
# 4769  [VII, ., Taxatorische, Vorerhebungen, und, Ber...
# 4771                                              [31.]
#
#                                                  labels          kind  \
# 0     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 2     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...     Predicted
# 4     [B-Cause, I-Cause, I-Cause, I-Cause, I-Cause, ...     Predicted
# 6     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 8     [O, B-Trigger, B-Effect, I-Effect, B-Trigger, ...     Predicted
# ...                                                 ...           ...
# 4759  [O, O, O, O, O, O, O, O, O, O, B-Cause, I-Caus...     Predicted
# 4765  [O, O, O, O, O, O, O, O, O, O, O, O, O, B-Caus...     Predicted
# 4767                                             [O, O]  Ground Truth
# 4769  [O, O, B-Effect, I-Effect, I-Effect, I-Effect,...     Predicted
# 4771                                                [O]  Ground Truth
#
#              type      degree  relation_id    id  fold
# 0            None        None            0     0     0
# 2      Motivation  Facilitate            0    10     0
# 4     Consequence  Facilitate            0    11     0
# 6            None        None            0    14     0
# 8     Consequence  Facilitate            0    16     0
# ...           ...         ...          ...   ...   ...
# 4759  Consequence  Facilitate            0  1677     4
# 4765  Consequence  Facilitate            0  1679     4
# 4767         None        None            0  1680     4
# 4769      Purpose  Facilitate            0  1688     4
# 4771         None        None            0  1691     4
#
# [1698 rows x 8 columns]
#                                                  tokens  \
# 0     [[, Datei, :, /media, /, bernhard, /, 40FE-DE2...
# 2     [Während, der, beherzte, Weidmann, im, Osten, ...
# 4     [In, diesem, Wechsel, der, Verhältnisse, sind,...
# 6     [Die, in, Verwaltung, des, Ackerbauministerium...
# 8     [Die, Ursachen, dieser, Erscheinung, sind, ein...
# ...                                                 ...
# 4752  [Zur, Flächenberechnung, im, Großen, verwendet...
# 4758  [Die, Flächen-Grössen, sind, in, der, zugehöri...
# 4760                                            [VI, .]
# 4762  [VII, ., Taxatorische, Vorerhebungen, und, Ber...
# 4764                                              [31.]
#
#                                                  labels          kind  \
# 0     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 2     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...     Predicted
# 4     [B-Cause, I-Cause, I-Cause, I-Cause, I-Cause, ...     Predicted
# 6     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 8     [O, B-Trigger, B-Effect, I-Effect, B-Trigger, ...     Predicted
# ...                                                 ...           ...
# 4752  [O, O, O, O, O, O, O, O, O, O, B-Cause, I-Caus...     Predicted
# 4758  [B-Affected, I-Affected, O, O, O, O, O, O, O, ...     Predicted
# 4760                                             [O, O]  Ground Truth
# 4762  [O, O, B-Effect, I-Effect, I-Effect, I-Effect,...     Predicted
# 4764                                                [O]  Ground Truth
#
#              type      degree  relation_id    id  fold
# 0            None        None            0     0     0
# 2      Motivation  Facilitate            0    10     0
# 4     Consequence  Facilitate            0    11     0
# 6            None        None            0    14     0
# 8      Motivation  Facilitate            0    16     0
# ...           ...         ...          ...   ...   ...
# 4752  Consequence  Facilitate            0  1677     4
# 4758  Consequence  Facilitate            0  1679     4
# 4760         None        None            0  1680     4
# 4762      Purpose  Facilitate            0  1688     4
# 4764         None        None            0  1691     4
#
# [1698 rows x 8 columns]

# %% [markdown]
# # Evaluate Coref

# %% [markdown]
# ## Arguments

# %%
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [coref_time, coref_name]]:

        results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_rehbein_dunietz.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased']:

            metric_results_model = {}
            trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
            metric_results_model["\textbf{" + "Trigger" + "}"] = f"{trigger_mean:.1f} ({trigger_std:.0f})"

            for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                
                if c_arg == "Controlling": c_arg = "Contr."
                if c_arg == "Affected": c_arg = "Aff."
                if c_arg == "Support": c_arg = "Sup."
                metric_results_model["\textbf{" + c_arg + "}"] = f"{c_arg_mean:.1f} ({c_arg_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": ["\multirow{3}{*}{\textbf{Original}}"] * 1 + ["RULE\multirow{3}{*}{\textbf{Coreference}}"] * 1,
        "  ": combined_results.index,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    # make largest result bold
    combined_results = combined_results.apply(bold_largest, axis=0)

    combined_results_sub = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Trigger", "Cause", "Effect", "Actor", "Aff.", "Sup.", "Contr."]]]
    display(combined_results_sub)

    # convert to latex and change some things
    latex_df = combined_results_sub.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
    latex_df = latex_df.replace("RULE", "\hline\n")
    latex_df = latex_df.replace("lllllllll", "clccccccc")
    latex_df = latex_df.replace(".0", "")
    latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
    latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Trigger\}", r"\\textbf{\\makecell{Pre-processing}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Trigger}", latex_df, flags=re.MULTILINE)
    print(metric_kind)
    print(latex_df)
# Out:
#                                                           \textbf{Trigger}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           49.2 (2)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{49.7 (2)}
#
#                                                             \textbf{Cause}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}  \textbf{28.7 (2)}
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}           28.1 (5)
#
#                                                            \textbf{Effect}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}  \textbf{31.0 (5)}
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}           29.7 (4)
#
#                                                              \textbf{Actor}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           33.0 (13)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{33.3 (11)}
#
#                                                              \textbf{Aff.}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           20.5 (6)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{21.8 (3)}
#
#                                                         \textbf{Sup.}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}       0.0 (0)
#
#                                                            \textbf{Contr.}
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}            5.8 (5)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{10.1 (7)}
# strict
# \begin{tabular}{clccccccc}
# \toprule
# \textbf{\makecell{Pre-processing}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Trigger} &     \textbf{Cause} &    \textbf{Effect} &      \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &    \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &           49.2 (2) &  \textbf{28.7 (2)} &  \textbf{31 (5)} &           33 (13) &           20.5 (6) &       0 (0) &            5.8 (5) \\
# \hline
# \multirow{3}{*}{\textbf{Coreference}} & \textbf{Ger.} &  \textbf{49.7 (2)} &           28.1 (5) &           29.7 (4) &  \textbf{33.3 (11)} &  \textbf{21.8 (3)} &       0 (0) &  \textbf{10.1 (7)} \\
# \bottomrule
# \end{tabular}
#                                                           \textbf{Trigger}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           49.2 (2)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{49.7 (2)}
#
#                                                             \textbf{Cause}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}  \textbf{52.7 (2)}
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}           52.5 (2)
#
#                                                            \textbf{Effect}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}  \textbf{59.4 (3)}
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}           58.8 (3)
#
#                                                              \textbf{Actor}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           36.0 (13)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{38.7 (12)}
#
#                                                              \textbf{Aff.}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}  \textbf{28.7 (8)}
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}           27.3 (4)
#
#                                                         \textbf{Sup.}  \
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}       0.0 (0)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}       0.0 (0)
#
#                                                            \textbf{Contr.}
#
# \multirow{3}{*}{\textbf{Original}}        \textbf{Ger.}           18.7 (3)
# RULE\multirow{3}{*}{\textbf{Coreference}} \textbf{Ger.}  \textbf{26.1 (8)}
# relaxed
# \begin{tabular}{clccccccc}
# \toprule
# \textbf{\makecell{Pre-processing}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Trigger} &     \textbf{Cause} &    \textbf{Effect} &      \textbf{Actor} &      \textbf{Aff.} & \textbf{Sup.} &    \textbf{Contr.} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &           49.2 (2) &  \textbf{52.7 (2)} &  \textbf{59.4 (3)} &           36 (13) &  \textbf{28.7 (8)} &       0 (0) &           18.7 (3) \\
# \hline
# \multirow{3}{*}{\textbf{Coreference}} & \textbf{Ger.} &  \textbf{49.7 (2)} &           52.5 (2) &           58.8 (3) &  \textbf{38.7 (12)} &           27.3 (4) &       0 (0) &  \textbf{26.1 (8)} \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results_all = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [coref_time, coref_name]]:

        transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
        for tl_name in transfer_learning_names:
            results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_{tl_name}.json"

            with open(results_path, "r") as f:
                results = json.load(f)

            metric_results = {}
            for model_kind in ['dbmdz/bert-base-german-cased']:

                metric_results_model = {}
                trigger_mean = np.mean([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
                trigger_std = np.std([results[model_kind]["oof_results_all"][fold]['detect_trigger_results'][f"overall_f1_{metric_kind}"] for fold in range(5)]) * 100
                metric_results_model["Trigger"] = trigger_mean

                for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]:
                    c_arg_mean = np.mean([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                    c_arg_std = np.std([results[model_kind]["oof_results_all"][fold]["detect_args_results"][f"{c_arg}_{metric_kind}_f1"] for fold in range(5)]) * 100
                    
                    metric_results_model[c_arg] = c_arg_mean

                metric_results[tl_name] = metric_results_model

            combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results, axis=0)

    index_df = pd.DataFrame({
        "Preprocessing": ["Original"]*4 + ["Coreference"]*4,
        "Transfer": ["\u2014", "BEC", "R&R", "R&R, BEC"]*2,
    })

    combined_results.index = pd.MultiIndex.from_frame(index_df)

    combined_results_sub = combined_results[[c_arg for c_arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]]]
    combined_results_sub["kind"] = metric_kind.title()

    combined_results_all.append(combined_results_sub)

combined_results_all = pd.concat(combined_results_all, axis=0).reset_index()
combined_results_all["Macro F1"] = combined_results_all[["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"]].mean(axis=1)
combined_results_all
# Out:
#    Preprocessing  Transfer      Cause     Effect      Actor   Affected  \
# 0       Original         —  25.555826  24.743564  32.740436  19.964839
# 1       Original       BEC  27.306735  25.814670  29.592922  20.220313
# 2       Original       R&R  26.389672  29.764783  31.306295  20.575285
# 3       Original  R&R, BEC  28.687005  31.025641  33.039614  20.469040
# 4    Coreference         —  24.643189  24.227430  26.004368  16.529214
# 5    Coreference       BEC  27.864601  27.366088  27.781494  20.346927
# 6    Coreference       R&R  28.642831  28.103135  31.493268  18.868041
# 7    Coreference  R&R, BEC  28.093781  29.684476  33.300144  21.823187
# 8       Original         —  49.550221  52.690052  44.521596  23.482625
# 9       Original       BEC  51.525570  54.763312  42.583226  27.203276
# 10      Original       R&R  51.505555  58.225900  36.744083  26.977739
# 11      Original  R&R, BEC  52.723945  59.448433  35.972947  28.745889
# 12   Coreference         —  49.306672  52.683438  32.424103  21.879659
# 13   Coreference       BEC  52.036987  54.716858  37.098972  25.958978
# 14   Coreference       R&R  51.361679  56.453231  38.562999  28.235044
# 15   Coreference  R&R, BEC  52.545185  58.814890  38.660414  27.267483
#
#     Support  Controlling     kind   Macro F1
# 0       0.0     8.039497   Strict  18.507360
# 1       0.0     9.006326   Strict  18.656828
# 2       0.0     8.742946   Strict  19.463163
# 3       0.0     5.810486   Strict  19.838631
# 4       0.0     4.311111   Strict  15.952552
# 5       0.0     7.565359   Strict  18.487411
# 6       0.0     7.256778   Strict  19.060675
# 7       0.0    10.112379   Strict  20.502328
# 8       0.0    24.811714  Relaxed  32.509368
# 9       0.0    29.472395  Relaxed  34.257963
# 10      0.0    19.934544  Relaxed  32.231304
# 11      0.0    18.676046  Relaxed  32.594543
# 12      0.0    24.307967  Relaxed  30.100307
# 13      0.0    18.140226  Relaxed  31.325337
# 14      0.0    16.445375  Relaxed  31.843055
# 15      0.0    26.090099  Relaxed  33.896345

# %%
import plotly.express as px

fig = go.Figure()

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Preprocessing", "Transfer", "Macro F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "Macro F1"]]

import plotly
cols = plotly.colors.DEFAULT_PLOTLY_COLORS

for i, pre in enumerate(strict_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("Preprocessing == @pre")["Transfer"],
        y=strict_f1.query("Preprocessing == @pre")["Macro F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(
            color=cols[i],
            size=10,
        ),        
        name=pre + " - Strict " ,
    ))

    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("Preprocessing == @pre")["Transfer"],
        y=relaxed_f1.query("Preprocessing == @pre")["Macro F1"],
        line=dict(width=2, color=cols[i], dash='dot'),
        marker=dict(
            color=cols[i],
            size=10,
        ),
        name=pre + " - Relaxed " ,
    ))

fig.update_layout(
    autosize=False,
    width=1200,
    height=600,
    xaxis_title="Transfer Learning Data",
    yaxis_title="Macro F1 Score",
    # yaxis2_title="Macro F1 Score",
    legend_title="Models",
    font=dict(
        size=18,
    ),
    template="plotly_white",
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#292828')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#292828')

fig.show()

fig.write_image("arguments_coref_comp.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="94f90a3b-8f78-4a76-9e03-b2122ef37d72" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94f90a3b-8f78-4a76-9e03-b2122ef37d72")) {                    Plotly.newPlot(                        "94f90a3b-8f78-4a76-9e03-b2122ef37d72",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"Original - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[18.50736031266104,18.65682770808164,19.463163459608438,19.83863103614909],"type":"scatter"},{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)","size":10},"name":"Original - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[32.50936787871439,34.25796304917028,32.23130363753817,32.594543193915555],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Coreference - Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[15.952551990867123,18.48741149648687,19.060675450494085,20.502327981812144],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)","size":10},"name":"Coreference - Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[30.100306562192074,31.325336697039763,31.843054739779173,33.89634523510472],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# ## Matched Relations

# %%
metric_kind_results = []
for metric_kind in ["strict", "relaxed"]:

    combined_results = []

    # experiment
    for t, n in [[time, name], [coref_time, coref_name]]:

        results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_rehbein_dunietz.json"

        with open(results_path, "r") as f:
            results = json.load(f)

        metric_results = {}
        for model_kind in ['dbmdz/bert-base-german-cased']:

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model["\textbf{" +metrics_dict[match_metric] + "}"] = f"{match_metric_mean:.1f} ({match_metric_std:.0f})"

            metric_results[model_names_dict[model_kind]] = metric_results_model

        combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)

    index_df = pd.DataFrame({
        " ": ["\multirow{3}{*}{\textbf{Original}}"] * 1 + ["RULE\multirow{3}{*}{\textbf{Corefernce}}"] * 1,
        "  ": combined_results.index,
    })


    combined_results.index = pd.MultiIndex.from_frame(index_df)
    # sort in order
    combined_results = combined_results[["\textbf{" + c_arg + "}" for c_arg in ["Precision", "Recall", "F1"]]]
    metric_kind_results.append(combined_results)

metric_kind_results = pd.concat(metric_kind_results, axis=1)
metric_kind_results = metric_kind_results.T

index_df = pd.DataFrame({
    "  ": ["\textbf{Strict}"] * 3 + ["\textbf{Relaxed}"] * 3,
    " ": metric_kind_results.index,
})

metric_kind_results.index = pd.MultiIndex.from_frame(index_df)
metric_kind_results = metric_kind_results.T

# make largest result bold
metric_kind_results = metric_kind_results.apply(bold_largest, axis=0)
display(metric_kind_results)

# convert to latex and change some things
latex_df = metric_kind_results.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("RULE", "\hline\n")
latex_df = latex_df.replace("llllllll", "clcccccc")
latex_df = latex_df.replace(".0", "")
latex_df = latex_df.replace("\multicolumn{3}{l}", "\multicolumn{3}{c}")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"Baseline[\s\&]+Baseline", r"\\multicolumn{2}{c}{\\textbf{Baseline}}", latex_df, flags=re.MULTILINE)
latex_df = re.sub(r"^\s*\&\s*&\s*\\textbf\{Precision\}", r"\\textbf{\\makecell{Pre-processing}} & \\textbf{\\makecell{BERT \\\\ Model}} & \\textbf{Precision}", latex_df, flags=re.MULTILINE)
print(latex_df)
# Out:
#                                                           \textbf{Strict}  \
#                                                        \textbf{Precision}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}   \textbf{8.8 (2)}
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}            7.1 (2)
#
#                                                                            \
#                                                           \textbf{Recall}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}  \textbf{12.7 (3)}
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}           10.6 (2)
#
#                                                                            \
#                                                               \textbf{F1}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}  \textbf{10.4 (2)}
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}            8.5 (2)
#
#                                                          \textbf{Relaxed}  \
#                                                        \textbf{Precision}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}  \textbf{54.3 (1)}
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}  \textbf{54.3 (3)}
#
#                                                                            \
#                                                           \textbf{Recall}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}           79.7 (3)
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}  \textbf{81.3 (2)}
#
#
#                                                               \textbf{F1}
#
# \multirow{3}{*}{\textbf{Original}}       \textbf{Ger.}           64.5 (0)
# RULE\multirow{3}{*}{\textbf{Corefernce}} \textbf{Ger.}  \textbf{65.0 (2)}
# \begin{tabular}{clcccccc}
# \toprule
#                                          &    & \multicolumn{3}{c}{\textbf{Strict}} & \multicolumn{3}{c}{\textbf{Relaxed}} \\
# \textbf{\makecell{Pre-processing}} & \textbf{\makecell{BERT \\ Model}} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} & \textbf{Precision} &    \textbf{Recall} &        \textbf{F1} \\
#
# \midrule
# \multirow{3}{*}{\textbf{Original}} & \textbf{Ger.} &   \textbf{8.8 (2)} &  \textbf{12.7 (3)} &  \textbf{10.4 (2)} &  \textbf{54.3 (1)} &           79.7 (3) &           64.5 (0) \\
# \hline
# \multirow{3}{*}{\textbf{Corefernce}} & \textbf{Ger.} &            7.1 (2) &           10.6 (2) &            8.5 (2) &  \textbf{54.3 (3)} &  \textbf{81.3 (2)} &  \textbf{65 (2)} \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Visualization

# %%
combined_results_all = []
for metric_kind in ["strict", "relaxed"]:
    combined_results = []

    # experiment
    for t, n in [[time, name], [coref_time, coref_name]]:

        # experiment
        transfer_learning_names = ["no_transfer", "dunietz", "rehbein", "rehbein_dunietz"]
        for tl_name in transfer_learning_names:

            results_path = PROJECT_PATH + f"output/{t}_{n}/"  + f"{corpus_name}_predictions_{t}_{tl_name}.json"

            with open(results_path, "r") as f:
                results = json.load(f)

            metric_results = {}
            model_kind = 'dbmdz/bert-base-german-cased'

            metric_results_model = {}
            for match_metric in ["precision", "recall", "f1"]:
                match_metric_mean = np.mean([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                match_metric_std = np.std([results[model_kind]["oof_results_all"][fold]["match_relations_results"][metric_kind][match_metric] for fold in range(5)]) * 100
                metric_results_model[metrics_dict[match_metric]] = match_metric_mean
                metric_results_model["Preprocessing"] = n
                metric_results_model["Transfer"] = transfer_learning_names_dict_base[tl_name]
                metric_results_model["kind"] = metric_kind.title()

            metric_results[model_kind] = metric_results_model

            combined_results.append(pd.DataFrame(metric_results).T)

    combined_results = pd.concat(combined_results)
    combined_results_all.append(combined_results)

combined_results_all = pd.concat(combined_results_all, axis=0).reset_index()

combined_results_all
# Out:
#                            index         F1  Precision Preprocessing  \
# 0   dbmdz/bert-base-german-cased   7.154313   6.369652  normal_valid
# 1   dbmdz/bert-base-german-cased    8.67251   7.657585  normal_valid
# 2   dbmdz/bert-base-german-cased   9.004887   7.421696  normal_valid
# 3   dbmdz/bert-base-german-cased  10.365927   8.753766  normal_valid
# 4   dbmdz/bert-base-german-cased   7.564494   6.700181         coref
# 5   dbmdz/bert-base-german-cased   8.698892   7.622586         coref
# 6   dbmdz/bert-base-german-cased   8.213675   6.709829         coref
# 7   dbmdz/bert-base-german-cased   8.454396   7.058418         coref
# 8   dbmdz/bert-base-german-cased  68.037232  60.529212  normal_valid
# 9   dbmdz/bert-base-german-cased     66.967  59.051532  normal_valid
# 10  dbmdz/bert-base-german-cased  62.878363  51.868575  normal_valid
# 11  dbmdz/bert-base-german-cased  64.540688  54.304967  normal_valid
# 12  dbmdz/bert-base-german-cased  65.769819  58.170314         coref
# 13  dbmdz/bert-base-german-cased  66.502854  58.212845         coref
# 14  dbmdz/bert-base-german-cased  62.854701  51.407578         coref
# 15  dbmdz/bert-base-german-cased  64.982513  54.273536         coref
#
#        Recall  Transfer     kind
# 0    8.189504         —   Strict
# 1    10.03458       BEC   Strict
# 2   11.490246       R&R   Strict
# 3   12.733431  R&R, BEC   Strict
# 4    8.724825         —   Strict
# 5   10.152759       BEC   Strict
# 6   10.609322       R&R   Strict
# 7   10.586515  R&R, BEC   Strict
# 8   77.981956         —  Relaxed
# 9   77.580118       BEC  Relaxed
# 10  80.148352       R&R  Relaxed
# 11  79.718223  R&R, BEC  Relaxed
# 12  75.975507         —  Relaxed
# 13   77.71151       BEC  Relaxed
# 14  81.017823       R&R  Relaxed
# 15  81.293085  R&R, BEC  Relaxed

# %%
fig = make_subplots(
    rows=2, cols=1,
    # subplot_titles=("Strict", "Relaxed"),
    subplot_titles=(" ", " "),
    shared_xaxes=True,
    vertical_spacing=0.05
)

strict_f1 = combined_results_all.query("kind == 'Strict'")[["Preprocessing", "Transfer", "F1"]]
relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "F1"]]

fig = go.Figure()

preprocess_dict = {
    "normal_valid": "Original",
    "coref": "Coreference",
}
for i, pre in enumerate(strict_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=strict_f1.query("Preprocessing == @pre")["Transfer"],
        y=strict_f1.query("Preprocessing == @pre")["F1"],
        line=dict(width=2, color=cols[i]),
        marker=dict(color=cols[i]),
        name=preprocess_dict[pre] + "<br>Strict "
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()

fig.write_image("matched_rel_coref_comb_strict.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bd9e6573-1699-4b9a-93c2-6bfe38f9fd68" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd9e6573-1699-4b9a-93c2-6bfe38f9fd68")) {                    Plotly.newPlot(                        "bd9e6573-1699-4b9a-93c2-6bfe38f9fd68",                        [{"line":{"color":"rgb(31, 119, 180)","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"Original<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.154312868190965,8.672510109758887,9.004887496029935,10.365927154085956],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Coreference<br>Strict ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[7.564493504617483,8.698892394433045,8.21367544110311,8.454396281125781],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"par ...

# %%
fig = make_subplots(
    rows=2, cols=1,
    # subplot_titles=("Strict", "Relaxed"),
    subplot_titles=(" ", " "),
    shared_xaxes=True,
    vertical_spacing=0.05
)

relaxed_f1 = combined_results_all.query("kind == 'Relaxed'")[["Preprocessing", "Transfer", "F1"]]

fig = go.Figure()

preprocess_dict = {
    "normal_valid": "Original",
    "coref": "Coreference",
}
for i, pre in enumerate(relaxed_f1["Preprocessing"].unique()):
    fig.add_trace(go.Scatter(
        x=relaxed_f1.query("Preprocessing == @pre")["Transfer"],
        y=relaxed_f1.query("Preprocessing == @pre")["F1"],
        line=dict(width=2, color=cols[i], dash="dot"),
        marker=dict(color=cols[i]),
        name=preprocess_dict[pre] + "<br>Relaxed "
    ))

fig.update_layout(
    autosize=False,
    width=750,
    height=450,
    xaxis_title="Transfer Learning Data",
    yaxis_title="F1 Score",
    # yaxis2_title="F1 Score",
    legend_title="Model",
    font=dict(
        size=18,
    ),
    template="plotly_white"
)

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='#595959')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='#595959')

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()

fig.write_image("matched_rel_coref_comb_relaxed.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="07f65e12-44d6-48b3-b36f-c3c6b8f32a79" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f65e12-44d6-48b3-b36f-c3c6b8f32a79")) {                    Plotly.newPlot(                        "07f65e12-44d6-48b3-b36f-c3c6b8f32a79",                        [{"line":{"color":"rgb(31, 119, 180)","dash":"dot","width":2},"marker":{"color":"rgb(31, 119, 180)"},"name":"Original<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[68.03723194755992,66.96700019710967,62.87836288475482,64.5406879967222],"type":"scatter"},{"line":{"color":"rgb(255, 127, 14)","dash":"dot","width":2},"marker":{"color":"rgb(255, 127, 14)"},"name":"Coreference<br>Relaxed ","x":["\u2014","BEC","R&R","R&R, BEC"],"y":[65.76981876406293,66.50285393620405,62.85470112687872,64.98251305472766],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth" ...

# %% [markdown]
# ## How well are coreferences predicted?

# %%
# normal results
results_path = PROJECT_PATH + f"output/{time}_{name}/"  + f"{corpus_name}_predictions_{time}_rehbein_dunietz.json"

with open(results_path, "r") as f:
    results= json.load(f)

oof_results = pd.DataFrame(results["dbmdz/bert-base-german-cased"]["oof_predictions"]).query("kind != 'Predicted without label'")
oof_results.head()


# coref results
results_path_coref = PROJECT_PATH + f"output/{coref_time}_{coref_name}/"  + f"{corpus_name}_predictions_{coref_time}_rehbein_dunietz.json"

with open(results_path_coref, "r") as f:
    results_coref = json.load(f)

oof_results_coref = pd.DataFrame(results_coref["dbmdz/bert-base-german-cased"]["oof_predictions"]).query("kind != 'Predicted without label'")
oof_results_coref.head()
# Out:
#                                               tokens  \
# 0  [[, Datei, :, /media, /, bernhard, /, 40FE-DE2...
# 1  [[, Datei, :, /media, /, bernhard, /, 40FE-DE2...
# 2  [Während, der, beherzte, Weidmann, im, Osten, ...
# 3  [Während, der, beherzte, Weidmann, im, Osten, ...
# 4  [In, diesem, Wechsel, der, Verhältnisse, sind,...
#
#                                               labels          kind  \
# 0  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 1  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...     Predicted
# 2  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...     Predicted
# 3  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...  Ground Truth
# 4  [B-Cause, I-Cause, I-Cause, I-Cause, I-Cause, ...     Predicted
#
#           type      degree  relation_id  id  fold
# 0         None        None            0   0     0
# 1         None        None            0   0     0
# 2   Motivation  Facilitate            0  10     0
# 3   Motivation  Facilitate            0  10     0
# 4  Consequence  Facilitate            0  11     0

# %%
correct_labels = []
pred_labels = []
random_labels = []

for id in tqdm(oof_results["id"].unique()[:]):
    orig_samples = oof_results.query("id == @id")
    coref_samples = oof_results_coref.query("id == @id")

    for rel_id in orig_samples["relation_id"].unique():
        orig_labels_gt = np.array(orig_samples.query("kind == 'Ground Truth' and relation_id == @rel_id").iloc[0]["labels"])
        coref_labels_gt = np.array(coref_samples.query("kind == 'Ground Truth' and relation_id == @rel_id").iloc[0]["labels"])

        # orig_labels_pred = np.array(orig_samples.query("kind == 'Predicted' and relation_id == @rel_id").iloc[0])
        coref_labels_pred = np.array(coref_samples.query("kind == 'Predicted' and relation_id == @rel_id").iloc[0]["labels"])

        if any(orig_labels_gt != coref_labels_gt): 

            coref_pos = np.where(orig_labels_gt != coref_labels_gt)[0]
            correct_labels.append(coref_labels_gt[coref_pos])
            pred_labels.append(coref_labels_pred[coref_pos])

            random_pos = np.random.choice(config["causal_arguments"] + ["O"], len(coref_pos))
            random_labels.append(random_pos)
# Out:
# 100%|██████████| 1698/1698 [00:26<00:00, 63.95it/s]

# %%
# Pred - True
pred_labels_no_prefix = np.array([label[2:] if label!="O" else "O" for label in flatten(pred_labels)])
true_labels_no_prefix = np.array([label[2:] if label!="O" else "O" for label in flatten(correct_labels)])
# tags_no_other = sorted(set(pred_labels_no_prefix + true_labels_no_prefix) - set(["O"]))

# preserve right order
# tags_no_other = [arg for arg in ["Cause", "Effect", "Actor", "Affected", "Support", "Controlling"] if arg in tags_no_other]

# report = classification_report_sk(true_labels_no_prefix, pred_labels_no_prefix, zero_division=False, labels=tags_no_other, output_dict=True)
# report_df = pd.DataFrame(report)


# # Random - True
# pred_labels_no_prefix = flatten(random_labels)
# report_rand = classification_report_sk(true_labels_no_prefix, pred_labels_no_prefix, zero_division=False, labels=tags_no_other, output_dict=True)

# report_rand_df = pd.DataFrame(report_rand)

# %%
from sklearn.metrics import matthews_corrcoef

results = {}
for arg in np.unique(np.concatenate([true_labels_no_prefix])):

    mcc = matthews_corrcoef(true_labels_no_prefix==arg, pred_labels_no_prefix==arg)
    results["\textbf{" + arg + "}"] = np.round(mcc*100, 2)

results["\textbf{Overall}"] = np.round(matthews_corrcoef(true_labels_no_prefix, pred_labels_no_prefix) * 100, 2)

print(pd.DataFrame(results, index=["\textbf{Coreference MCC}"]).to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}"))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  \textbf{Actor} &  \textbf{Affected} &  \textbf{Cause} &  \textbf{Effect} &  \textbf{Overall} \\
# \midrule
# \textbf{Coreference MCC} &            -2.6 &               39.9 &           -3.93 &             15.4 &              9.03 \\
# \bottomrule
# \end{tabular}

# %%
confusion_matrix(true_labels_no_prefix, pred_labels_no_prefix)
# Out:
# array([[ 0,  0,  0,  0, 25],
#        [ 0, 10,  4,  0, 36],
#        [ 1,  0,  6,  6, 42],
#        [ 0,  0, 17, 10, 49],
#        [ 0,  0,  0,  0,  0]])

# %%
matthews_corrcoef(true_labels_no_prefix, pred_labels_no_prefix)
# Out:
# 0.0902764898399391

# %%
pred_labels_no_prefix
# Out:
# array(['Affected', 'Affected', 'Affected', 'Affected', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'Effect', 'Effect', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'Cause', 'Cause', 'Cause', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Effect', 'Effect', 'Effect', 'Effect', 'O', 'Affected',
#        'Affected', 'O', 'O', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Cause', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Effect',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Cause', 'Cause', 'Cause', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'Affected', 'Affected', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'Cause', 'Cause', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Cause', 'Cause', 'Effect', 'Effect', 'Actor', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Affected',
#        'Affected', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect'], dtype='<U8')

# %%
true_labels_no_prefix
# Out:
# array(['Affected', 'Affected', 'Affected', 'Affected', 'Affected',
#        'Affected', 'Affected', 'Affected', 'Affected', 'Affected',
#        'Affected', 'Cause', 'Cause', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Actor', 'Actor', 'Actor', 'Actor', 'Actor', 'Actor',
#        'Actor', 'Actor', 'Actor', 'Actor', 'Actor', 'Actor', 'Actor',
#        'Actor', 'Cause', 'Cause', 'Cause', 'Cause', 'Affected',
#        'Affected', 'Affected', 'Affected', 'Affected', 'Cause', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Affected', 'Affected',
#        'Affected', 'Affected', 'Affected', 'Affected', 'Affected',
#        'Affected', 'Affected', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Actor', 'Actor', 'Actor',
#        'Affected', 'Effect', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Affected', 'Affected', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Affected', 'Affected',
#        'Affected', 'Cause', 'Cause', 'Affected', 'Affected', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Affected', 'Affected', 'Affected', 'Effect',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Actor', 'Actor', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Affected',
#        'Affected', 'Affected', 'Affected', 'Affected', 'Effect', 'Effect',
#        'Effect', 'Effect', 'Affected', 'Affected', 'Effect', 'Effect',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Affected',
#        'Affected', 'Affected', 'Affected', 'Affected', 'Actor', 'Actor',
#        'Affected', 'Affected', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Cause', 'Cause', 'Actor', 'Actor', 'Actor', 'Actor', 'Cause',
#        'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause', 'Cause',
#        'Effect', 'Effect', 'Effect', 'Effect', 'Effect', 'Effect',
#        'Effect', 'Effect'], dtype='<U8')

# %%
matthews_corrcoef(["a", "a", "a", "b"], ["a", "a", "b", "a"])
# Out:
# -0.3333333333333333

# %%
y_true = ["a", "a", "a", "b"]
y_pred = ["a", "b", "a", "c"]
matthews_corrcoef(y_true, y_pred)
# Out:
# 0.12909944487358055

# %%
res = defaultdict(list)

for i in tqdm(range(10000)):
    for arg in tags_no_other:
        score = f1_score(
            true_labels_no_prefix, np.random.choice(config["causal_arguments"] + ["O"], len(true_labels_no_prefix)), 
            zero_division=False, labels=[arg], average="micro"
        )

        res[arg].append(score)

for arg in res:
    print(arg, np.mean(res[arg]))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-69b30958b10e> in <module>()
#       2
#       3 for i in tqdm(range(10000)):
# ----> 4     for arg in tags_no_other:
#       5         score = f1_score(
#       6             true_labels_no_prefix, np.random.choice(config["causal_arguments"] + ["O"], len(true_labels_no_prefix)),
#
# NameError: name 'tags_no_other' is not defined

# %%
comb_df = pd.DataFrame({
    "Model": report_df[tags_no_other].loc["f1-score"] * 100,
    "Random": report_df[tags_no_other].loc["support"].astype(int).apply(lambda n_a: n_a / ((4*n_a) + report_df.loc["support", "micro avg"]/2)) * 100, #report_rand_df[tags_no_other].loc["f1-score"] * 100,
}).T.round(2).astype(str)

comb_df.columns = ["\textbf{" + arg + "}" for arg in comb_df.columns]
comb_df.index = ["\textbf{" + arg + "}" for arg in comb_df.index]

comb_df = comb_df.apply(bold_largest, axis=0)
# comb_df.loc["\textbf{Num Tokens}"] = report_df[tags_no_other].loc["support"].astype(int).values
display(comb_df)

latex_df = comb_df.to_latex().replace('textbackslash ', '').replace("\{", "{").replace("\}", "}")
latex_df = latex_df.replace("\\textbf{Random}", "\\hline\n\\textbf{Random}")
latex_df = latex_df.replace("lllll", "lcccc")
latex_df = latex_df.replace("\textbf{Random}", "\\hline\n\textbf{Random}")
latex_df = latex_df.replace(".0", "")
latex_df = re.sub(r"^[\\\s\&]+$", "", latex_df, flags=re.MULTILINE)
print(latex_df)
